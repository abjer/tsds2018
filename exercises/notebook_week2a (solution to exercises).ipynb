# %%
from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
        'width': int(1024*1.2),
        'height': 768,
        'scroll':True
})

# %%
# load dependencies
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import json
import pickle

# %% [markdown]
# # Agenda

# %% [markdown]
# ## Focus of today
# * Recap of the essentials of web scraping.
#     * Navigating html, reliable connection, parsing, storing, logging.
#
# * Showing you some tricks of the trade
# * Hands on with APIs
#
# ...
# * Pointing to the skills you need to master.

# %% [markdown]
# ## Motivation
# <a href="https://imgflip.com/i/24m2p1"><img src="https://i.imgflip.com/24m2p1.jpg" title="made at imgflip.com"/></a>

# %% [markdown]
# ## Main take-away
# * Central problem you are facing is *ensuring* and *demonstrating* **data quality** by:
#     * Logging,
#         * the scraping process
#         * the parse
#     * ensuring reproducibility (storing raw data)
#     * inspections (random selections of your parse)
#     * exploratory data analysis.

# %% [markdown]
# # Quick setup - connecting and legal notice

# %% [markdown]
# ## Ethics / Legal Issues
# * If a regular user can’t access it, we shouldn’t try to get it (That is considered hacking)https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking.
# * Don't hit it to fast: Essentially a DENIAL OF SERVICE attack (DOS). [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb).
# * Add headers stating your name and email with your requests to ensure transparency.
# * Be careful with copyrighted material.
# * Fair use (don't take everything)
# * If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from.
# * Who are you collecting data about?
#     * Political groups, minorities or organizations, or all at the same time?

# %% [markdown]
# ## Connecting

# %%
# Transparent scraping
import requests
#response = requests.get('https://www.google.com')
session = requests.session()
session.headers['email'] = 'youremail' 
session.headers['name'] = 'name'
session.headers
# Out:
# {'User-Agent': 'python-requests/2.18.4', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'email': 'youremail', 'name': 'name'}

# %% [markdown]
# A quick tip is that you can change the user agent to a cellphone to obtain more simple formatting of the html.

# %%
# Control the pace of your calls
import time
def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # change to design more clever schemes for handling the rate of calls.
# Reliable requests
def request(url,iterations=10,exceptions=(Exception)):
    """This module ensures that your script does not crash from connection errors.
        iterations : Define number of iterations before giving up. 
        exceptions: Define which exceptions you accept, default is all. 
    """
    for iteration in range(iterations):
        try:
            # add ratelimit function call here
            ratelimit() # !!
            response = session.get(url)
            return response # if succesful it will end the iterations here
        except exceptions as e: #  find exceptions in the request library requests.exceptions
            print(e) # print or log the exception message.
    return None # your code will purposely crash if you don't create a check function later.

# %%
# Interactive browsing. 
# Need to download geckodrivers (https://github.com/mozilla/geckodriver/releases) and install selenium first
from selenium import webdriver
path2gecko = '/Users/axelengbergpallesen/Downloads/geckodriver' # define path to your geckodriver
browser = webdriver.Firefox(executable_path=path2gecko)
browser.get('https://www.facebook.com')

# %% [markdown]
# # Essentials of webscraping

# %% [markdown]
# ## Essentials (1): Reading html
# * Using the Inspector
#     * locating paths to elements: e.g css selectors
#     * structure of the html-tree
#     * uncover hidden information e.g. extra meta data.
#     * Find direct links to the underlying database. Visit (https://www.jobnet.dk)

# %%
url = 'https://job.jobnet.dk/CV/FindWork?SearchString=it&Offset=0&SortValue=BestMatch'
response = request(url)

# %% [markdown]
# ## Essentials(2): Navigation
# - http hacking: Visit https://www.jobindex.dk
# - crawling and following links
# - interactions
#     * send keys: e.g. login
#     * clicks
#     * scroll-down (https://stackoverflow.com/questions/20986631/how-can-i-scroll-a-web-page-using-selenium-webdriver-in-python)

# %%
# hardcoded interaction
css_sel = 'html#facebook.tinyViewport.tinyWidth.tinyHeight body.fbIndex.UIPage_LoggedOut.hasBanner._-kb.sf._61s0.b_c3pyn-ahh.gecko.mac.x1.Locale_da_DK.cores-lt4.hasCookieBanner.hasAXNavMenubar._19_u div#u_0_d._li div#pagelet_bluebar div#blueBarDOMInspector div._53jh div.loggedout_menubar_container div.clearfix.loggedout_menubar div.menu_login_container.rfloat._ohf form#login_form table tbody tr td input#email.inputtext'
element = browser.find_element_by_css_selector(css_sel)
username = 'hello'
element.send_keys(username)

# %% [markdown]
# ## Essentials(3): Parsing

# %%
import re # generic pattern search
from bs4 import BeautifulSoup # navigating the html tree
'Scraping,2,is,3,easy,6,?'.split(',')[::2] # good old split function
# Out:
# ['Scraping', 'is', 'easy', '?']

# %% [markdown]
# ![](http://www.tankonyvtar.hu/hu/tartalom/tamop412A/2011_0015_kliens_oldali_technologiak_EN/files/4018.jpg)

# %%
url = 'https://it.jobindex.dk/jobsoegning?maxdate=20180214&mindate=20171101&jobage=archive'
response = request(url)
soup = BeautifulSoup(response.text,'lxml')

# %%
# lets find the section with the results.
results = soup.findAll('div',{'class':'results  component--default'})
results
# Out:
# []

# %% [markdown]
# ** shit! ** it is dynamically generated.
#
# Now we have the possibility of using selenium or inpecting the network acitivty / following the html build instructions.

# %%
url = 'https://it.jobindex.dk/jobsoegning.json?q=&jobage=archive&mindate=20171101&maxdate=20180214&page=0'
response = request(url)
if response.ok:
    
    print('response is OK')
    soup = BeautifulSoup(response.json()['result_list_box_html'],'lxml')
# Out:
# response is OK

# %%
results = soup.find('div',{'class':'results component--default'})
for child in results.findAll('div'):
    break
    # getting links.
    relative_link = child.a['data-click']

    # getting headlines.
    headline = child.b.text
    # company
    company = child.p.a.b.text

# %% [markdown]
# ## Essentials(4): Storing, and formatting

# %%
f = open(filename,'w')
#formats
#raw,pickle,json, csv
f.write()
json.dump(), json.dumps
csv.writer
pd.to_csv,pd.to_pickle,pd.to_feather 
# for arbitrary python objects
pickle.dump
# Databases.

# %%
! mkdir jobindex_raw

# %%
# paging the first 5
for page_n in range(5):
    url = 'https://it.jobindex.dk/jobsoegning.json?q=&jobage=archive&mindate=20171101&maxdate=20180214&page=%d'%page_n
    response = request(url)
    # store it.
    break
    if response.ok:
        path = 'jobindex_raw/jobindex_page_%d'%page_n
        f = open(path,'w')
        f.write(response.text)
        f.close()

# %%
data = json.loads(response.text)

# %% [markdown]
# ## Essentials (5): Logging and Quality Controls

# %%
response = request('https://www.google.com')

# %%
# setting up the logfile
! mkdir logs
log_id = 0 
logfile = open('logs/test_log','w') 
log_header = ['log_id','status_code','timestamp','length','output_file']  # 
logfile.write(','.join(log_header)) # comment this out after the first write
logfile.close()

# %%
logfile = open('logs/test_log','a') 
import time
def log(response,output_path,logfile=logfile):
    "A simple example of a logging function"
    global log_id
    # give it an id
    log_id += 1
    status_code = response.status_code
    timestamp = time.time()
    length = len(response.text)
    # Header 'log_id','status_code','timestamp','length','output_file'
    logfile.write('%d,%d,%r,%d,%s'%(log_id,status_code,timestamp,length,output_path))
    # add a write function here
    
! mkdir test_scrape
log(response,'test_scrape/google.com')
# Out:
# 13236

# %% [markdown]
# ## Quality of the parse
# * Number of missing values accross different Variables, and accross different sites or subsections of a site.
# * If temporal data: quality accross time.
# * Profile missing values
#     * Might be related to time of day, rate of calls, length of the response, or other more complex factors logged.
# * Do many random samples of the parse and checks of the final dataframe or dataset.
#     * E.g. do random sample in pandas like this: df.sample(frac=0.1).head()

# %% [markdown]
# # Scraping the Cryptomarkets to investigate rate of success, bots and scams.

# %% [markdown]
# ## Exercise (1)
# Visit following page: https://coinmarketcap.com/
#
# The page allows you to investigate the ***"big"*** players of the cryptomarket.
#
# ** Navigation **
# - Find a way to navigate the page and extract links to the blockchain companies.

# %% [markdown]
# ## Solutions (1)
# - First visit following page: https://coinmarketcap.com/
# - Look in the network: find the quick-search jsonfile.

# %%
# this is a site note, just wanted to show you how to parse a table from html using pandas.
response = request('https://coinmarketcap.com/')
coin_df = pd.read_html(response.text,attrs={'id':'currencies'}) # using pandas to parse the table.

# %%
coin_df[0].head()
# Out:
#    #              Name        Market Cap     Price    Volume (24h)  \
# 0  1       BTC Bitcoin  $164,813,477,318  $9771.77  $8,477,880,000
# 1  2      ETH Ethereum   $90,729,788,972   $929.32  $2,958,370,000
# 2  3        XRP Ripple   $43,932,178,877     $1.13  $1,590,210,000
# 3  4  BCH Bitcoin Cash   $22,866,525,417  $1347.55    $651,822,000
# 4  5      LTC Litecoin   $12,496,631,350   $226.28  $2,504,410,000
#
#      Circulating Supply Change (24h)  Price Graph (7d)
# 0        16,866,287 BTC        6.00%               NaN
# 1        97,630,298 ETH        4.12%               NaN
# 2  39,009,215,838 XRP *        5.29%               NaN
# 3        16,968,963 BCH        3.39%               NaN
# 4        55,227,383 LTC       10.58%               NaN

# %%
url = 'https://files.coinmarketcap.com/generated/search/quick_search.json'
coins = request(url).json()

# %%
coins
# Out:
# [{'name': 'Bitcoin',
#   'rank': 1,
#   'slug': 'bitcoin',
#   'symbol': 'BTC',
#   'tokens': ['Bitcoin', 'BTC']},
#  {'name': 'Ethereum',
#   'rank': 2,
#   'slug': 'ethereum',
#   'symbol': 'ETH',
#   'tokens': ['Ethereum', 'ETH']},
#  {'name': 'Ripple',
#   'rank': 3,
#   'slug': 'ripple',
#   'symbol': 'XRP',
#   'tokens': ['Ripple', 'XRP']},
#  {'name': 'Bitcoin Cash',
#   'rank': 4,
#   'slug': 'bitcoin-cash',
#   'symbol': 'BCH',
#   'tokens': ['Bitcoin Cash', 'BCH']},
#  {'name': 'Litecoin',
#   'rank': 5,
#   'slug': 'litecoin',
#   'symbol': 'LTC',
#   'tokens': ['Litecoin', 'LTC']},
#  {'name': 'Cardano',
#   'rank': 6,
#   'slug': 'cardano',
#   'symbol': 'ADA',
#   'tokens': ['Cardano', 'ADA']},
#  {'name': 'Stellar',
#   'rank': 7,
#   'slug': 'stellar',
#   'symbol': 'XLM',
#   'tokens': ['Stellar', 'XLM']},
#  {'name': 'NEO',
#   'rank': 8,
#   'slug': 'neo',
#   'symbol': 'NEO',
#   'tokens': ['NEO', 'NEO']},
#  {'name': 'EOS',
#   'rank': 9,
#   'slug': 'eos',
#   'symbol': 'EOS',
#   'tokens': ['EOS', 'EOS']},
#  {'name': 'IOTA',
#   'rank': 10,
#   'slug': 'iota',
#   'symbol': 'MIOTA',
#   'tokens': ['IOTA', 'MIOTA']},
#  {'name': 'Dash',
#   'rank': 11,
#   'slug': 'dash',
#   'symbol': 'DASH',
#   'tokens': ['Dash', 'DASH']},
#  {'name': 'NEM',
#   'rank': 12,
#   'slug': 'nem',
#   'symbol': 'XEM',
#   'tokens': ['NEM', 'XEM']},
#  {'name': 'Monero',
#   'rank': 13,
#   'slug': 'monero',
#   'symbol': 'XMR',
#   'tokens': ['Monero', 'XMR']},
#  {'name': 'Ethereum Classic',
#   'rank': 14,
#   'slug': 'ethereum-classic',
#   'symbol': 'ETC',
#   'tokens': ['Ethereum Classic', 'ETC']},
#  {'name': 'Lisk',
#   'rank': 15,
#   'slug': 'lisk',
#   'symbol': 'LSK',
#   'tokens': ['Lisk', 'LSK']},
#  {'name': 'TRON',
#   'rank': 16,
#   'slug': 'tron',
#   'symbol': 'TRX',
#   'tokens': ['TRON', 'TRX']},
#  {'name': 'Qtum',
#   'rank': 17,
#   'slug': 'qtum',
#   'symbol': 'QTUM',
#   'tokens': ['Qtum', 'QTUM']},
#  {'name': 'Tether',
#   'rank': 18,
#   'slug': 'tether',
#   'symbol': 'USDT',
#   'tokens': ['Tether', 'USDT']},
#  {'name': 'VeChain',
#   'rank': 19,
#   'slug': 'vechain',
#   'symbol': 'VEN',
#   'tokens': ['VeChain', 'VEN']},
#  {'name': 'Bitcoin Gold',
#   'rank': 20,
#   'slug': 'bitcoin-gold',
#   'symbol': 'BTG',
#   'tokens': ['Bitcoin Gold', 'BTG']},
#  {'name': 'ICON',
#   'rank': 21,
#   'slug': 'icon',
#   'symbol': 'ICX',
#   'tokens': ['ICON', 'ICX']},
#  {'name': 'OmiseGO',
#   'rank': 22,
#   'slug': 'omisego',
#   'symbol': 'OMG',
#   'tokens': ['OmiseGO', 'OMG']},
#  {'name': 'Zcash',
#   'rank': 23,
#   'slug': 'zcash',
#   'symbol': 'ZEC',
#   'tokens': ['Zcash', 'ZEC']},
#  {'name': 'Nano',
#   'rank': 24,
#   'slug': 'raiblocks',
#   'symbol': 'XRB',
#   'tokens': ['Nano', 'XRB']},
#  {'name': 'Steem',
#   'rank': 25,
#   'slug': 'steem',
#   'symbol': 'STEEM',
#   'tokens': ['Steem', 'STEEM']},
#  {'name': 'Binance Coin',
#   'rank': 26,
#   'slug': 'binance-coin',
#   'symbol': 'BNB',
#   'tokens': ['Binance Coin', 'BNB']},
#  {'name': 'Bytecoin',
#   'rank': 27,
#   'slug': 'bytecoin-bcn',
#   'symbol': 'BCN',
#   'tokens': ['Bytecoin', 'BCN']},
#  {'name': 'Populous',
#   'rank': 28,
#   'slug': 'populous',
#   'symbol': 'PPT',
#   'tokens': ['Populous', 'PPT']},
#  {'name': 'Stratis',
#   'rank': 29,
#   'slug': 'stratis',
#   'symbol': 'STRAT',
#   'tokens': ['Stratis', 'STRAT']},
#  {'name': 'Verge',
#   'rank': 30,
#   'slug': 'verge',
#   'symbol': 'XVG',
#   'tokens': ['Verge', 'XVG']},
#  {'name': 'Siacoin',
#   'rank': 31,
#   'slug': 'siacoin',
#   'symbol': 'SC',
#   'tokens': ['Siacoin', 'SC']},
#  {'name': 'RChain',
#   'rank': 32,
#   'slug': 'rchain',
#   'symbol': 'RHOC',
#   'tokens': ['RChain', 'RHOC']},
#  {'name': 'Status',
#   'rank': 33,
#   'slug': 'status',
#   'symbol': 'SNT',
#   'tokens': ['Status', 'SNT']},
#  {'name': 'Dogecoin',
#   'rank': 34,
#   'slug': 'dogecoin',
#   'symbol': 'DOGE',
#   'tokens': ['Dogecoin', 'DOGE']},
#  {'name': 'BitShares',
#   'rank': 35,
#   'slug': 'bitshares',
#   'symbol': 'BTS',
#   'tokens': ['BitShares', 'BTS']},
#  {'name': 'Maker',
#   'rank': 36,
#   'slug': 'maker',
#   'symbol': 'MKR',
#   'tokens': ['Maker', 'MKR']},
#  {'name': 'Waves',
#   'rank': 37,
#   'slug': 'waves',
#   'symbol': 'WAVES',
#   'tokens': ['Waves', 'WAVES']},
#  {'name': 'Aeternity',
#   'rank': 38,
#   'slug': 'aeternity',
#   'symbol': 'AE',
#   'tokens': ['Aeternity', 'AE']},
#  {'name': 'Veritaseum',
#   'rank': 39,
#   'slug': 'veritaseum',
#   'symbol': 'VERI',
#   'tokens': ['Veritaseum', 'VERI']},
#  {'name': 'Revain',
#   'rank': 40,
#   'slug': 'revain',
#   'symbol': 'R',
#   'tokens': ['Revain', 'R']},
#  {'name': 'Waltonchain',
#   'rank': 41,
#   'slug': 'walton',
#   'symbol': 'WTC',
#   'tokens': ['Waltonchain', 'WTC']},
#  {'name': 'Augur',
#   'rank': 42,
#   'slug': 'augur',
#   'symbol': 'REP',
#   'tokens': ['Augur', 'REP']},
#  {'name': 'Hshare',
#   'rank': 43,
#   'slug': 'hshare',
#   'symbol': 'HSR',
#   'tokens': ['Hshare', 'HSR']},
#  {'name': '0x',
#   'rank': 44,
#   'slug': '0x',
#   'symbol': 'ZRX',
#   'tokens': ['0x', 'ZRX']},
#  {'name': 'U.CASH',
#   'rank': 45,
#   'slug': 'ucash',
#   'symbol': 'UCASH',
#   'tokens': ['U.CASH', 'UCASH']},
#  {'name': 'ZClassic',
#   'rank': 46,
#   'slug': 'zclassic',
#   'symbol': 'ZCL',
#   'tokens': ['ZClassic', 'ZCL']},
#  {'name': 'Decred',
#   'rank': 47,
#   'slug': 'decred',
#   'symbol': 'DCR',
#   'tokens': ['Decred', 'DCR']},
#  {'name': 'KuCoin Shares',
#   'rank': 48,
#   'slug': 'kucoin-shares',
#   'symbol': 'KCS',
#   'tokens': ['KuCoin Shares', 'KCS']},
#  {'name': 'Ardor',
#   'rank': 49,
#   'slug': 'ardor',
#   'symbol': 'ARDR',
#   'tokens': ['Ardor', 'ARDR']},
#  {'name': 'DigixDAO',
#   'rank': 50,
#   'slug': 'digixdao',
#   'symbol': 'DGD',
#   'tokens': ['DigixDAO', 'DGD']},
#  {'name': 'Komodo',
#   'rank': 51,
#   'slug': 'komodo',
#   'symbol': 'KMD',
#   'tokens': ['Komodo', 'KMD']},
#  {'name': 'Electroneum',
#   'rank': 52,
#   'slug': 'electroneum',
#   'symbol': 'ETN',
#   'tokens': ['Electroneum', 'ETN']},
#  {'name': 'Dragonchain',
#   'rank': 53,
#   'slug': 'dragonchain',
#   'symbol': 'DRGN',
#   'tokens': ['Dragonchain', 'DRGN']},
#  {'name': 'Ark',
#   'rank': 54,
#   'slug': 'ark',
#   'symbol': 'ARK',
#   'tokens': ['Ark', 'ARK']},
#  {'name': 'Byteball Bytes',
#   'rank': 55,
#   'slug': 'byteball',
#   'symbol': 'GBYTE',
#   'tokens': ['Byteball Bytes', 'GBYTE']},
#  {'name': 'Gas',
#   'rank': 56,
#   'slug': 'gas',
#   'symbol': 'GAS',
#   'tokens': ['Gas', 'GAS']},
#  {'name': 'DigiByte',
#   'rank': 57,
#   'slug': 'digibyte',
#   'symbol': 'DGB',
#   'tokens': ['DigiByte', 'DGB']},
#  {'name': 'Basic Attention Token',
#   'rank': 58,
#   'slug': 'basic-attention-token',
#   'symbol': 'BAT',
#   'tokens': ['Basic Attention Token', 'BAT']},
#  {'name': 'Bytom',
#   'rank': 59,
#   'slug': 'bytom',
#   'symbol': 'BTM',
#   'tokens': ['Bytom', 'BTM']},
#  {'name': 'Loopring',
#   'rank': 60,
#   'slug': 'loopring',
#   'symbol': 'LRC',
#   'tokens': ['Loopring', 'LRC']},
#  {'name': 'Dentacoin',
#   'rank': 61,
#   'slug': 'dentacoin',
#   'symbol': 'DCN',
#   'tokens': ['Dentacoin', 'DCN']},
#  {'name': 'Kyber Network',
#   'rank': 62,
#   'slug': 'kyber-network',
#   'symbol': 'KNC',
#   'tokens': ['Kyber Network', 'KNC']},
#  {'name': 'Zilliqa',
#   'rank': 63,
#   'slug': 'zilliqa',
#   'symbol': 'ZIL',
#   'tokens': ['Zilliqa', 'ZIL']},
#  {'name': 'PIVX',
#   'rank': 64,
#   'slug': 'pivx',
#   'symbol': 'PIVX',
#   'tokens': ['PIVX', 'PIVX']},
#  {'name': 'Syscoin',
#   'rank': 65,
#   'slug': 'syscoin',
#   'symbol': 'SYS',
#   'tokens': ['Syscoin', 'SYS']},
#  {'name': 'Golem',
#   'rank': 66,
#   'slug': 'golem-network-tokens',
#   'symbol': 'GNT',
#   'tokens': ['Golem', 'GNT']},
#  {'name': 'aelf',
#   'rank': 67,
#   'slug': 'aelf',
#   'symbol': 'ELF',
#   'tokens': ['aelf', 'ELF']},
#  {'name': 'QASH',
#   'rank': 68,
#   'slug': 'qash',
#   'symbol': 'QASH',
#   'tokens': ['QASH', 'QASH']},
#  {'name': 'Nebulas',
#   'rank': 69,
#   'slug': 'nebulas-token',
#   'symbol': 'NAS',
#   'tokens': ['Nebulas', 'NAS']},
#  {'name': 'Bitcore',
#   'rank': 70,
#   'slug': 'bitcore',
#   'symbol': 'BTX',
#   'tokens': ['Bitcore', 'BTX']},
#  {'name': 'Cryptonex',
#   'rank': 71,
#   'slug': 'cryptonex',
#   'symbol': 'CNX',
#   'tokens': ['Cryptonex', 'CNX']},
#  {'name': 'Ethos',
#   'rank': 72,
#   'slug': 'ethos',
#   'symbol': 'ETHOS',
#   'tokens': ['Ethos', 'ETHOS']},
#  {'name': 'GXShares',
#   'rank': 73,
#   'slug': 'gxshares',
#   'symbol': 'GXS',
#   'tokens': ['GXShares', 'GXS']},
#  {'name': 'Power Ledger',
#   'rank': 74,
#   'slug': 'power-ledger',
#   'symbol': 'POWR',
#   'tokens': ['Power Ledger', 'POWR']},
#  {'name': 'Pillar',
#   'rank': 75,
#   'slug': 'pillar',
#   'symbol': 'PLR',
#   'tokens': ['Pillar', 'PLR']},
#  {'name': 'IOStoken',
#   'rank': 76,
#   'slug': 'iostoken',
#   'symbol': 'IOST',
#   'tokens': ['IOStoken', 'IOST']},
#  {'name': 'Factom',
#   'rank': 77,
#   'slug': 'factom',
#   'symbol': 'FCT',
#   'tokens': ['Factom', 'FCT']},
#  {'name': 'Dent',
#   'rank': 78,
#   'slug': 'dent',
#   'symbol': 'DENT',
#   'tokens': ['Dent', 'DENT']},
#  {'name': 'Cindicator',
#   'rank': 79,
#   'slug': 'cindicator',
#   'symbol': 'CND',
#   'tokens': ['Cindicator', 'CND']},
#  {'name': 'FunFair',
#   'rank': 80,
#   'slug': 'funfair',
#   'symbol': 'FUN',
#   'tokens': ['FunFair', 'FUN']},
#  {'name': 'MonaCoin',
#   'rank': 81,
#   'slug': 'monacoin',
#   'symbol': 'MONA',
#   'tokens': ['MonaCoin', 'MONA']},
#  {'name': 'Aion',
#   'rank': 82,
#   'slug': 'aion',
#   'symbol': 'AION',
#   'tokens': ['Aion', 'AION']},
#  {'name': 'Polymath',
#   'rank': 83,
#   'slug': 'polymath-network',
#   'symbol': 'POLY',
#   'tokens': ['Polymath', 'POLY']},
#  {'name': 'Enigma',
#   'rank': 84,
#   'slug': 'enigma-project',
#   'symbol': 'ENG',
#   'tokens': ['Enigma', 'ENG']},
#  {'name': 'ZCoin',
#   'rank': 85,
#   'slug': 'zcoin',
#   'symbol': 'XZC',
#   'tokens': ['ZCoin', 'XZC']},
#  {'name': 'Kin',
#   'rank': 86,
#   'slug': 'kin',
#   'symbol': 'KIN',
#   'tokens': ['Kin', 'KIN']},
#  {'name': 'SALT',
#   'rank': 87,
#   'slug': 'salt',
#   'symbol': 'SALT',
#   'tokens': ['SALT', 'SALT']},
#  {'name': 'Nxt',
#   'rank': 88,
#   'slug': 'nxt',
#   'symbol': 'NXT',
#   'tokens': ['Nxt', 'NXT']},
#  {'name': 'ReddCoin',
#   'rank': 89,
#   'slug': 'reddcoin',
#   'symbol': 'RDD',
#   'tokens': ['ReddCoin', 'RDD']},
#  {'name': 'MaidSafeCoin',
#   'rank': 90,
#   'slug': 'maidsafecoin',
#   'symbol': 'MAID',
#   'tokens': ['MaidSafeCoin', 'MAID']},
#  {'name': 'Bancor',
#   'rank': 91,
#   'slug': 'bancor',
#   'symbol': 'BNT',
#   'tokens': ['Bancor', 'BNT']},
#  {'name': 'Particl',
#   'rank': 92,
#   'slug': 'particl',
#   'symbol': 'PART',
#   'tokens': ['Particl', 'PART']},
#  {'name': 'TenX',
#   'rank': 93,
#   'slug': 'tenx',
#   'symbol': 'PAY',
#   'tokens': ['TenX', 'PAY']},
#  {'name': 'ChainLink',
#   'rank': 94,
#   'slug': 'chainlink',
#   'symbol': 'LINK',
#   'tokens': ['ChainLink', 'LINK']},
#  {'name': 'Request Network',
#   'rank': 95,
#   'slug': 'request-network',
#   'symbol': 'REQ',
#   'tokens': ['Request Network', 'REQ']},
#  {'name': 'SmartCash',
#   'rank': 96,
#   'slug': 'smartcash',
#   'symbol': 'SMART',
#   'tokens': ['SmartCash', 'SMART']},
#  {'name': 'Experience Points',
#   'rank': 97,
#   'slug': 'experience-points',
#   'symbol': 'XP',
#   'tokens': ['Experience Points', 'XP']},
#  {'name': 'Ignis',
#   'rank': 98,
#   'slug': 'ignis',
#   'symbol': 'IGNIS',
#   'tokens': ['Ignis', 'IGNIS']},
#  {'name': 'Quantstamp',
#   'rank': 99,
#   'slug': 'quantstamp',
#   'symbol': 'QSP',
#   'tokens': ['Quantstamp', 'QSP']},
#  {'name': 'SingularityNET',
#   'rank': 100,
#   'slug': 'singularitynet',
#   'symbol': 'AGI',
#   'tokens': ['SingularityNET', 'AGI']},
#  {'name': 'Emercoin',
#   'rank': 101,
#   'slug': 'emercoin',
#   'symbol': 'EMC',
#   'tokens': ['Emercoin', 'EMC']},
#  {'name': 'Neblio',
#   'rank': 102,
#   'slug': 'neblio',
#   'symbol': 'NEBL',
#   'tokens': ['Neblio', 'NEBL']},
#  {'name': 'Blocknet',
#   'rank': 103,
#   'slug': 'blocknet',
#   'symbol': 'BLOCK',
#   'tokens': ['Blocknet', 'BLOCK']},
#  {'name': 'Gnosis',
#   'rank': 104,
#   'slug': 'gnosis-gno',
#   'symbol': 'GNO',
#   'tokens': ['Gnosis', 'GNO']},
#  {'name': 'Iconomi',
#   'rank': 105,
#   'slug': 'iconomi',
#   'symbol': 'ICN',
#   'tokens': ['Iconomi', 'ICN']},
#  {'name': 'Po.et',
#   'rank': 106,
#   'slug': 'poet',
#   'symbol': 'POE',
#   'tokens': ['Po.et', 'POE']},
#  {'name': 'Substratum',
#   'rank': 107,
#   'slug': 'substratum',
#   'symbol': 'SUB',
#   'tokens': ['Substratum', 'SUB']},
#  {'name': 'WAX',
#   'rank': 108,
#   'slug': 'wax',
#   'symbol': 'WAX',
#   'tokens': ['WAX', 'WAX']},
#  {'name': 'DigitalNote',
#   'rank': 109,
#   'slug': 'digitalnote',
#   'symbol': 'XDN',
#   'tokens': ['DigitalNote', 'XDN']},
#  {'name': 'GameCredits',
#   'rank': 110,
#   'slug': 'gamecredits',
#   'symbol': 'GAME',
#   'tokens': ['GameCredits', 'GAME']},
#  {'name': 'Civic',
#   'rank': 111,
#   'slug': 'civic',
#   'symbol': 'CVC',
#   'tokens': ['Civic', 'CVC']},
#  {'name': 'XPA',
#   'rank': 112,
#   'slug': 'xplay',
#   'symbol': 'XPA',
#   'tokens': ['XPA', 'XPA']},
#  {'name': 'Vertcoin',
#   'rank': 113,
#   'slug': 'vertcoin',
#   'symbol': 'VTC',
#   'tokens': ['Vertcoin', 'VTC']},
#  {'name': 'BitcoinDark',
#   'rank': 114,
#   'slug': 'bitcoindark',
#   'symbol': 'BTCD',
#   'tokens': ['BitcoinDark', 'BTCD']},
#  {'name': 'Nexus',
#   'rank': 115,
#   'slug': 'nexus',
#   'symbol': 'NXS',
#   'tokens': ['Nexus', 'NXS']},
#  {'name': 'SuperNET',
#   'rank': 116,
#   'slug': 'supernet-unity',
#   'symbol': 'UNITY',
#   'tokens': ['SuperNET', 'UNITY']},
#  {'name': 'Raiden Network Token',
#   'rank': 117,
#   'slug': 'raiden-network-token',
#   'symbol': 'RDN',
#   'tokens': ['Raiden Network Token', 'RDN']},
#  {'name': 'Storj',
#   'rank': 118,
#   'slug': 'storj',
#   'symbol': 'STORJ',
#   'tokens': ['Storj', 'STORJ']},
#  {'name': 'Red Pulse',
#   'rank': 119,
#   'slug': 'red-pulse',
#   'symbol': 'RPX',
#   'tokens': ['Red Pulse', 'RPX']},
#  {'name': 'Skycoin',
#   'rank': 120,
#   'slug': 'skycoin',
#   'symbol': 'SKY',
#   'tokens': ['Skycoin', 'SKY']},
#  {'name': 'High Performance Blockchain',
#   'rank': 121,
#   'slug': 'high-performance-blockchain',
#   'symbol': 'HPB',
#   'tokens': ['High Performance Blockchain', 'HPB']},
#  {'name': 'ZenCash',
#   'rank': 122,
#   'slug': 'zencash',
#   'symbol': 'ZEN',
#   'tokens': ['ZenCash', 'ZEN']},
#  {'name': 'DEW',
#   'rank': 123,
#   'slug': 'dew',
#   'symbol': 'DEW',
#   'tokens': ['DEW', 'DEW']},
#  {'name': 'Dynamic Trading Rights',
#   'rank': 124,
#   'slug': 'dynamic-trading-rights',
#   'symbol': 'DTR',
#   'tokens': ['Dynamic Trading Rights', 'DTR']},
#  {'name': 'Santiment Network Token',
#   'rank': 125,
#   'slug': 'santiment',
#   'symbol': 'SAN',
#   'tokens': ['Santiment Network Token', 'SAN']},
#  {'name': 'Decentraland',
#   'rank': 126,
#   'slug': 'decentraland',
#   'symbol': 'MANA',
#   'tokens': ['Decentraland', 'MANA']},
#  {'name': 'SIRIN LABS Token',
#   'rank': 127,
#   'slug': 'sirin-labs-token',
#   'symbol': 'SRN',
#   'tokens': ['SIRIN LABS Token', 'SRN']},
#  {'name': 'PayPie',
#   'rank': 128,
#   'slug': 'paypie',
#   'symbol': 'PPP',
#   'tokens': ['PayPie', 'PPP']},
#  {'name': 'PACcoin',
#   'rank': 129,
#   'slug': 'paccoin',
#   'symbol': 'PAC',
#   'tokens': ['PACcoin', 'PAC']},
#  {'name': 'Aragon',
#   'rank': 130,
#   'slug': 'aragon',
#   'symbol': 'ANT',
#   'tokens': ['Aragon', 'ANT']},
#  {'name': 'Enjin Coin',
#   'rank': 131,
#   'slug': 'enjin-coin',
#   'symbol': 'ENJ',
#   'tokens': ['Enjin Coin', 'ENJ']},
#  {'name': 'NAV Coin',
#   'rank': 132,
#   'slug': 'nav-coin',
#   'symbol': 'NAV',
#   'tokens': ['NAV Coin', 'NAV']},
#  {'name': 'Time New Bank',
#   'rank': 133,
#   'slug': 'time-new-bank',
#   'symbol': 'TNB',
#   'tokens': ['Time New Bank', 'TNB']},
#  {'name': 'MediBloc',
#   'rank': 134,
#   'slug': 'medibloc',
#   'symbol': 'MED',
#   'tokens': ['MediBloc', 'MED']},
#  {'name': 'Achain',
#   'rank': 135,
#   'slug': 'achain',
#   'symbol': 'ACT',
#   'tokens': ['Achain', 'ACT']},
#  {'name': 'iExec RLC',
#   'rank': 136,
#   'slug': 'rlc',
#   'symbol': 'RLC',
#   'tokens': ['iExec RLC', 'RLC']},
#  {'name': 'Monaco',
#   'rank': 137,
#   'slug': 'monaco',
#   'symbol': 'MCO',
#   'tokens': ['Monaco', 'MCO']},
#  {'name': 'Ubiq',
#   'rank': 138,
#   'slug': 'ubiq',
#   'symbol': 'UBQ',
#   'tokens': ['Ubiq', 'UBQ']},
#  {'name': 'BLOCKv',
#   'rank': 139,
#   'slug': 'blockv',
#   'symbol': 'VEE',
#   'tokens': ['BLOCKv', 'VEE']},
#  {'name': 'DeepBrain Chain',
#   'rank': 140,
#   'slug': 'deepbrain-chain',
#   'symbol': 'DBC',
#   'tokens': ['DeepBrain Chain', 'DBC']},
#  {'name': 'HTMLCOIN',
#   'rank': 141,
#   'slug': 'html-coin',
#   'symbol': 'HTML',
#   'tokens': ['HTMLCOIN', 'HTML']},
#  {'name': 'ETHLend',
#   'rank': 142,
#   'slug': 'ethlend',
#   'symbol': 'LEND',
#   'tokens': ['ETHLend', 'LEND']},
#  {'name': 'Agoras Tokens',
#   'rank': 143,
#   'slug': 'agoras-tokens',
#   'symbol': 'AGRS',
#   'tokens': ['Agoras Tokens', 'AGRS']},
#  {'name': 'Bluzelle',
#   'rank': 144,
#   'slug': 'bluzelle',
#   'symbol': 'BLZ',
#   'tokens': ['Bluzelle', 'BLZ']},
#  {'name': 'Storm',
#   'rank': 145,
#   'slug': 'storm',
#   'symbol': 'STORM',
#   'tokens': ['Storm', 'STORM']},
#  {'name': 'SophiaTX',
#   'rank': 146,
#   'slug': 'sophiatx',
#   'symbol': 'SPHTX',
#   'tokens': ['SophiaTX', 'SPHTX']},
#  {'name': 'XTRABYTES',
#   'rank': 147,
#   'slug': 'xtrabytes',
#   'symbol': 'XBY',
#   'tokens': ['XTRABYTES', 'XBY']},
#  {'name': 'Bibox Token',
#   'rank': 148,
#   'slug': 'bibox-token',
#   'symbol': 'BIX',
#   'tokens': ['Bibox Token', 'BIX']},
#  {'name': 'CRYPTO20',
#   'rank': 149,
#   'slug': 'c20',
#   'symbol': 'C20',
#   'tokens': ['CRYPTO20', 'C20']},
#  {'name': 'Ripio Credit Network',
#   'rank': 150,
#   'slug': 'ripio-credit-network',
#   'symbol': 'RCN',
#   'tokens': ['Ripio Credit Network', 'RCN']},
#  {'name': 'MediShares',
#   'rank': 151,
#   'slug': 'medishares',
#   'symbol': 'MDS',
#   'tokens': ['MediShares', 'MDS']},
#  {'name': 'IoT Chain',
#   'rank': 152,
#   'slug': 'iot-chain',
#   'symbol': 'ITC',
#   'tokens': ['IoT Chain', 'ITC']},
#  {'name': 'Einsteinium',
#   'rank': 153,
#   'slug': 'einsteinium',
#   'symbol': 'EMC2',
#   'tokens': ['Einsteinium', 'EMC2']},
#  {'name': 'Counterparty',
#   'rank': 154,
#   'slug': 'counterparty',
#   'symbol': 'XCP',
#   'tokens': ['Counterparty', 'XCP']},
#  {'name': 'AirSwap',
#   'rank': 155,
#   'slug': 'airswap',
#   'symbol': 'AST',
#   'tokens': ['AirSwap', 'AST']},
#  {'name': 'VIBE',
#   'rank': 156,
#   'slug': 'vibe',
#   'symbol': 'VIBE',
#   'tokens': ['VIBE', 'VIBE']},
#  {'name': 'Peercoin',
#   'rank': 157,
#   'slug': 'peercoin',
#   'symbol': 'PPC',
#   'tokens': ['Peercoin', 'PPC']},
#  {'name': 'Jibrel Network',
#   'rank': 158,
#   'slug': 'jibrel-network',
#   'symbol': 'JNT',
#   'tokens': ['Jibrel Network', 'JNT']},
#  {'name': 'CyberMiles',
#   'rank': 159,
#   'slug': 'cybermiles',
#   'symbol': 'CMT',
#   'tokens': ['CyberMiles', 'CMT']},
#  {'name': 'Cobinhood',
#   'rank': 160,
#   'slug': 'cobinhood',
#   'symbol': 'COB',
#   'tokens': ['Cobinhood', 'COB']},
#  {'name': 'BridgeCoin',
#   'rank': 161,
#   'slug': 'bridgecoin',
#   'symbol': 'BCO',
#   'tokens': ['BridgeCoin', 'BCO']},
#  {'name': 'Telcoin',
#   'rank': 162,
#   'slug': 'telcoin',
#   'symbol': 'TEL',
#   'tokens': ['Telcoin', 'TEL']},
#  {'name': 'Simple Token',
#   'rank': 163,
#   'slug': 'simple-token',
#   'symbol': 'OST',
#   'tokens': ['Simple Token', 'OST']},
#  {'name': 'AdEx',
#   'rank': 164,
#   'slug': 'adx-net',
#   'symbol': 'ADX',
#   'tokens': ['AdEx', 'ADX']},
#  {'name': 'SingularDTV',
#   'rank': 165,
#   'slug': 'singulardtv',
#   'symbol': 'SNGLS',
#   'tokens': ['SingularDTV', 'SNGLS']},
#  {'name': 'SONM',
#   'rank': 166,
#   'slug': 'sonm',
#   'symbol': 'SNM',
#   'tokens': ['SONM', 'SNM']},
#  {'name': 'Asch',
#   'rank': 167,
#   'slug': 'asch',
#   'symbol': 'XAS',
#   'tokens': ['Asch', 'XAS']},
#  {'name': 'Metal',
#   'rank': 168,
#   'slug': 'metal',
#   'symbol': 'MTL',
#   'tokens': ['Metal', 'MTL']},
#  {'name': 'Eidoo',
#   'rank': 169,
#   'slug': 'eidoo',
#   'symbol': 'EDO',
#   'tokens': ['Eidoo', 'EDO']},
#  {'name': 'BitBay',
#   'rank': 170,
#   'slug': 'bitbay',
#   'symbol': 'BAY',
#   'tokens': ['BitBay', 'BAY']},
#  {'name': 'Viacoin',
#   'rank': 171,
#   'slug': 'viacoin',
#   'symbol': 'VIA',
#   'tokens': ['Viacoin', 'VIA']},
#  {'name': 'Ambrosus',
#   'rank': 172,
#   'slug': 'amber',
#   'symbol': 'AMB',
#   'tokens': ['Ambrosus', 'AMB']},
#  {'name': 'SpankChain',
#   'rank': 173,
#   'slug': 'spankchain',
#   'symbol': 'SPANK',
#   'tokens': ['SpankChain', 'SPANK']},
#  {'name': 'WaBi',
#   'rank': 174,
#   'slug': 'wabi',
#   'symbol': 'WABI',
#   'tokens': ['WaBi', 'WABI']},
#  {'name': 'Trinity Network Credit',
#   'rank': 175,
#   'slug': 'trinity-network-credit',
#   'symbol': 'TNC',
#   'tokens': ['Trinity Network Credit', 'TNC']},
#  {'name': 'MobileGo',
#   'rank': 176,
#   'slug': 'mobilego',
#   'symbol': 'MGO',
#   'tokens': ['MobileGo', 'MGO']},
#  {'name': 'Theta Token',
#   'rank': 177,
#   'slug': 'theta-token',
#   'symbol': 'THETA',
#   'tokens': ['Theta Token', 'THETA']},
#  {'name': 'Melon',
#   'rank': 178,
#   'slug': 'melon',
#   'symbol': 'MLN',
#   'tokens': ['Melon', 'MLN']},
#  {'name': 'UTRUST',
#   'rank': 179,
#   'slug': 'utrust',
#   'symbol': 'UTK',
#   'tokens': ['UTRUST', 'UTK']},
#  {'name': 'Edgeless',
#   'rank': 180,
#   'slug': 'edgeless',
#   'symbol': 'EDG',
#   'tokens': ['Edgeless', 'EDG']},
#  {'name': 'Wagerr',
#   'rank': 181,
#   'slug': 'wagerr',
#   'symbol': 'WGR',
#   'tokens': ['Wagerr', 'WGR']},
#  {'name': 'Metaverse ETP',
#   'rank': 182,
#   'slug': 'metaverse',
#   'symbol': 'ETP',
#   'tokens': ['Metaverse ETP', 'ETP']},
#  {'name': 'Quantum Resistant Ledger',
#   'rank': 183,
#   'slug': 'quantum-resistant-ledger',
#   'symbol': 'QRL',
#   'tokens': ['Quantum Resistant Ledger', 'QRL']},
#  {'name': 'Modum',
#   'rank': 184,
#   'slug': 'modum',
#   'symbol': 'MOD',
#   'tokens': ['Modum', 'MOD']},
#  {'name': 'Rise',
#   'rank': 185,
#   'slug': 'rise',
#   'symbol': 'RISE',
#   'tokens': ['Rise', 'RISE']},
#  {'name': 'INS Ecosystem',
#   'rank': 186,
#   'slug': 'ins-ecosystem',
#   'symbol': 'INS',
#   'tokens': ['INS Ecosystem', 'INS']},
#  {'name': 'district0x',
#   'rank': 187,
#   'slug': 'district0x',
#   'symbol': 'DNT',
#   'tokens': ['district0x', 'DNT']},
#  {'name': 'Streamr DATAcoin',
#   'rank': 188,
#   'slug': 'streamr-datacoin',
#   'symbol': 'DATA',
#   'tokens': ['Streamr DATAcoin', 'DATA']},
#  {'name': 'Bread',
#   'rank': 189,
#   'slug': 'bread',
#   'symbol': 'BRD',
#   'tokens': ['Bread', 'BRD']},
#  {'name': 'Gulden',
#   'rank': 190,
#   'slug': 'gulden',
#   'symbol': 'NLG',
#   'tokens': ['Gulden', 'NLG']},
#  {'name': 'QLINK',
#   'rank': 191,
#   'slug': 'qlink',
#   'symbol': 'QLC',
#   'tokens': ['QLINK', 'QLC']},
#  {'name': 'Wings',
#   'rank': 192,
#   'slug': 'wings',
#   'symbol': 'WINGS',
#   'tokens': ['Wings', 'WINGS']},
#  {'name': 'Tierion',
#   'rank': 193,
#   'slug': 'tierion',
#   'symbol': 'TNT',
#   'tokens': ['Tierion', 'TNT']},
#  {'name': 'Centra',
#   'rank': 194,
#   'slug': 'centra',
#   'symbol': 'CTR',
#   'tokens': ['Centra', 'CTR']},
#  {'name': 'AppCoins',
#   'rank': 195,
#   'slug': 'appcoins',
#   'symbol': 'APPC',
#   'tokens': ['AppCoins', 'APPC']},
#  {'name': 'Genesis Vision',
#   'rank': 196,
#   'slug': 'genesis-vision',
#   'symbol': 'GVT',
#   'tokens': ['Genesis Vision', 'GVT']},
#  {'name': 'All Sports',
#   'rank': 197,
#   'slug': 'all-sports',
#   'symbol': 'SOC',
#   'tokens': ['All Sports', 'SOC']},
#  {'name': 'Nuls',
#   'rank': 198,
#   'slug': 'nuls',
#   'symbol': 'NULS',
#   'tokens': ['Nuls', 'NULS']},
#  {'name': 'Etherparty',
#   'rank': 199,
#   'slug': 'etherparty',
#   'symbol': 'FUEL',
#   'tokens': ['Etherparty', 'FUEL']},
#  {'name': 'ION',
#   'rank': 200,
#   'slug': 'ion',
#   'symbol': 'ION',
#   'tokens': ['ION', 'ION']},
#  {'name': 'Unikoin Gold',
#   'rank': 201,
#   'slug': 'unikoin-gold',
#   'symbol': 'UKG',
#   'tokens': ['Unikoin Gold', 'UKG']},
#  {'name': 'MinexCoin',
#   'rank': 202,
#   'slug': 'minexcoin',
#   'symbol': 'MNX',
#   'tokens': ['MinexCoin', 'MNX']},
#  {'name': 'Oyster',
#   'rank': 203,
#   'slug': 'oyster',
#   'symbol': 'PRL',
#   'tokens': ['Oyster', 'PRL']},
#  {'name': 'CoinDash',
#   'rank': 204,
#   'slug': 'coindash',
#   'symbol': 'CDT',
#   'tokens': ['CoinDash', 'CDT']},
#  {'name': 'Triggers',
#   'rank': 205,
#   'slug': 'triggers',
#   'symbol': 'TRIG',
#   'tokens': ['Triggers', 'TRIG']},
#  {'name': 'Pura',
#   'rank': 206,
#   'slug': 'pura',
#   'symbol': 'PURA',
#   'tokens': ['Pura', 'PURA']},
#  {'name': 'Internet Node Token',
#   'rank': 207,
#   'slug': 'internet-node-token',
#   'symbol': 'INT',
#   'tokens': ['Internet Node Token', 'INT']},
#  {'name': 'LBRY Credits',
#   'rank': 208,
#   'slug': 'library-credit',
#   'symbol': 'LBC',
#   'tokens': ['LBRY Credits', 'LBC']},
#  {'name': 'Burst',
#   'rank': 209,
#   'slug': 'burst',
#   'symbol': 'BURST',
#   'tokens': ['Burst', 'BURST']},
#  {'name': 'Gifto',
#   'rank': 210,
#   'slug': 'gifto',
#   'symbol': 'GTO',
#   'tokens': ['Gifto', 'GTO']},
#  {'name': 'ECC',
#   'rank': 211,
#   'slug': 'eccoin',
#   'symbol': 'ECC',
#   'tokens': ['ECC', 'ECC']},
#  {'name': 'NAGA',
#   'rank': 212,
#   'slug': 'naga',
#   'symbol': 'NGC',
#   'tokens': ['NAGA', 'NGC']},
#  {'name': 'Hive',
#   'rank': 213,
#   'slug': 'hive',
#   'symbol': 'HVN',
#   'tokens': ['Hive', 'HVN']},
#  {'name': 'OriginTrail',
#   'rank': 214,
#   'slug': 'origintrail',
#   'symbol': 'TRAC',
#   'tokens': ['OriginTrail', 'TRAC']},
#  {'name': 'SaluS',
#   'rank': 215,
#   'slug': 'salus',
#   'symbol': 'SLS',
#   'tokens': ['SaluS', 'SLS']},
#  {'name': 'Mercury',
#   'rank': 216,
#   'slug': 'mercury',
#   'symbol': 'MER',
#   'tokens': ['Mercury', 'MER']},
#  {'name': 'ATMChain',
#   'rank': 217,
#   'slug': 'attention-token-of-media',
#   'symbol': 'ATM',
#   'tokens': ['ATMChain', 'ATM']},
#  {'name': 'Aeon',
#   'rank': 218,
#   'slug': 'aeon',
#   'symbol': 'AEON',
#   'tokens': ['Aeon', 'AEON']},
#  {'name': 'COSS',
#   'rank': 219,
#   'slug': 'coss',
#   'symbol': 'COSS',
#   'tokens': ['COSS', 'COSS']},
#  {'name': 'adToken',
#   'rank': 220,
#   'slug': 'adtoken',
#   'symbol': 'ADT',
#   'tokens': ['adToken', 'ADT']},
#  {'name': 'Safe Exchange Coin',
#   'rank': 221,
#   'slug': 'safe-exchange-coin',
#   'symbol': 'SAFEX',
#   'tokens': ['Safe Exchange Coin', 'SAFEX']},
#  {'name': 'TaaS',
#   'rank': 222,
#   'slug': 'taas',
#   'symbol': 'TAAS',
#   'tokens': ['TaaS', 'TAAS']},
#  {'name': 'Electra',
#   'rank': 223,
#   'slug': 'electra',
#   'symbol': 'ECA',
#   'tokens': ['Electra', 'ECA']},
#  {'name': 'Groestlcoin',
#   'rank': 224,
#   'slug': 'groestlcoin',
#   'symbol': 'GRS',
#   'tokens': ['Groestlcoin', 'GRS']},
#  {'name': 'Crown',
#   'rank': 225,
#   'slug': 'crown',
#   'symbol': 'CRW',
#   'tokens': ['Crown', 'CRW']},
#  {'name': 'Steem Dollars',
#   'rank': 226,
#   'slug': 'steem-dollars',
#   'symbol': 'SBD',
#   'tokens': ['Steem Dollars', 'SBD']},
#  {'name': 'Presearch',
#   'rank': 227,
#   'slug': 'presearch',
#   'symbol': 'PRE',
#   'tokens': ['Presearch', 'PRE']},
#  {'name': 'Delphy',
#   'rank': 228,
#   'slug': 'delphy',
#   'symbol': 'DPY',
#   'tokens': ['Delphy', 'DPY']},
#  {'name': 'indaHash',
#   'rank': 229,
#   'slug': 'indahash',
#   'symbol': 'IDH',
#   'tokens': ['indaHash', 'IDH']},
#  {'name': 'DeepOnion',
#   'rank': 230,
#   'slug': 'deeponion',
#   'symbol': 'ONION',
#   'tokens': ['DeepOnion', 'ONION']},
#  {'name': 'Viberate',
#   'rank': 231,
#   'slug': 'viberate',
#   'symbol': 'VIB',
#   'tokens': ['Viberate', 'VIB']},
#  {'name': 'DECENT',
#   'rank': 232,
#   'slug': 'decent',
#   'symbol': 'DCT',
#   'tokens': ['DECENT', 'DCT']},
#  {'name': 'Decision Token',
#   'rank': 233,
#   'slug': 'decision-token',
#   'symbol': 'HST',
#   'tokens': ['Decision Token', 'HST']},
#  {'name': 'FirstBlood',
#   'rank': 234,
#   'slug': 'firstblood',
#   'symbol': '1ST',
#   'tokens': ['FirstBlood', '1ST']},
#  {'name': 'Dimecoin',
#   'rank': 235,
#   'slug': 'dimecoin',
#   'symbol': 'DIME',
#   'tokens': ['Dimecoin', 'DIME']},
#  {'name': 'CloakCoin',
#   'rank': 236,
#   'slug': 'cloakcoin',
#   'symbol': 'CLOAK',
#   'tokens': ['CloakCoin', 'CLOAK']},
#  {'name': 'I/O Coin',
#   'rank': 237,
#   'slug': 'iocoin',
#   'symbol': 'IOC',
#   'tokens': ['I/O Coin', 'IOC']},
#  {'name': 'Datum',
#   'rank': 238,
#   'slug': 'datum',
#   'symbol': 'DAT',
#   'tokens': ['Datum', 'DAT']},
#  {'name': 'HempCoin',
#   'rank': 239,
#   'slug': 'hempcoin',
#   'symbol': 'THC',
#   'tokens': ['HempCoin', 'THC']},
#  {'name': 'Qbao',
#   'rank': 240,
#   'slug': 'qbao',
#   'symbol': 'QBT',
#   'tokens': ['Qbao', 'QBT']},
#  {'name': 'Energo',
#   'rank': 241,
#   'slug': 'energo',
#   'symbol': 'TSL',
#   'tokens': ['Energo', 'TSL']},
#  {'name': 'Cappasity',
#   'rank': 242,
#   'slug': 'cappasity',
#   'symbol': 'CAPP',
#   'tokens': ['Cappasity', 'CAPP']},
#  {'name': 'Nimiq',
#   'rank': 243,
#   'slug': 'nimiq',
#   'symbol': 'NET',
#   'tokens': ['Nimiq', 'NET']},
#  {'name': 'Pepe Cash',
#   'rank': 244,
#   'slug': 'pepe-cash',
#   'symbol': 'PEPECASH',
#   'tokens': ['Pepe Cash', 'PEPECASH']},
#  {'name': 'Lykke',
#   'rank': 245,
#   'slug': 'lykke',
#   'symbol': 'LKK',
#   'tokens': ['Lykke', 'LKK']},
#  {'name': 'Lunyr',
#   'rank': 246,
#   'slug': 'lunyr',
#   'symbol': 'LUN',
#   'tokens': ['Lunyr', 'LUN']},
#  {'name': 'LOCIcoin',
#   'rank': 247,
#   'slug': 'locicoin',
#   'symbol': 'LOCI',
#   'tokens': ['LOCIcoin', 'LOCI']},
#  {'name': 'Namecoin',
#   'rank': 248,
#   'slug': 'namecoin',
#   'symbol': 'NMC',
#   'tokens': ['Namecoin', 'NMC']},
#  {'name': 'TokenCard',
#   'rank': 249,
#   'slug': 'tokencard',
#   'symbol': 'TKN',
#   'tokens': ['TokenCard', 'TKN']},
#  {'name': 'Odyssey',
#   'rank': 250,
#   'slug': 'odyssey',
#   'symbol': 'OCN',
#   'tokens': ['Odyssey', 'OCN']},
#  {'name': 'Game.com',
#   'rank': 251,
#   'slug': 'game',
#   'symbol': 'GTC',
#   'tokens': ['Game.com', 'GTC']},
#  {'name': 'Shift',
#   'rank': 252,
#   'slug': 'shift',
#   'symbol': 'SHIFT',
#   'tokens': ['Shift', 'SHIFT']},
#  {'name': 'Ink',
#   'rank': 253,
#   'slug': 'ink',
#   'symbol': 'INK',
#   'tokens': ['Ink', 'INK']},
#  {'name': 'Feathercoin',
#   'rank': 254,
#   'slug': 'feathercoin',
#   'symbol': 'FTC',
#   'tokens': ['Feathercoin', 'FTC']},
#  {'name': 'Humaniq',
#   'rank': 255,
#   'slug': 'humaniq',
#   'symbol': 'HMQ',
#   'tokens': ['Humaniq', 'HMQ']},
#  {'name': 'Diamond',
#   'rank': 256,
#   'slug': 'diamond',
#   'symbol': 'DMD',
#   'tokens': ['Diamond', 'DMD']},
#  {'name': 'Agrello',
#   'rank': 257,
#   'slug': 'agrello-delta',
#   'symbol': 'DLT',
#   'tokens': ['Agrello', 'DLT']},
#  {'name': 'BitDegree',
#   'rank': 258,
#   'slug': 'bitdegree',
#   'symbol': 'BDG',
#   'tokens': ['BitDegree', 'BDG']},
#  {'name': 'Monetha',
#   'rank': 259,
#   'slug': 'monetha',
#   'symbol': 'MTH',
#   'tokens': ['Monetha', 'MTH']},
#  {'name': 'Rivetz',
#   'rank': 260,
#   'slug': 'rivetz',
#   'symbol': 'RVT',
#   'tokens': ['Rivetz', 'RVT']},
#  {'name': 'Cofound.it',
#   'rank': 261,
#   'slug': 'cofound-it',
#   'symbol': 'CFI',
#   'tokens': ['Cofound.it', 'CFI']},
#  {'name': 'bitCNY',
#   'rank': 262,
#   'slug': 'bitcny',
#   'symbol': 'BITCNY',
#   'tokens': ['bitCNY', 'BITCNY']},
#  {'name': 'carVertical',
#   'rank': 263,
#   'slug': 'carvertical',
#   'symbol': 'CV',
#   'tokens': ['carVertical', 'CV']},
#  {'name': 'Mooncoin',
#   'rank': 264,
#   'slug': 'mooncoin',
#   'symbol': 'MOON',
#   'tokens': ['Mooncoin', 'MOON']},
#  {'name': 'SwftCoin',
#   'rank': 265,
#   'slug': 'swftcoin',
#   'symbol': 'SWFTC',
#   'tokens': ['SwftCoin', 'SWFTC']},
#  {'name': 'SIBCoin',
#   'rank': 266,
#   'slug': 'sibcoin',
#   'symbol': 'SIB',
#   'tokens': ['SIBCoin', 'SIB']},
#  {'name': 'BitConnect',
#   'rank': 267,
#   'slug': 'bitconnect',
#   'symbol': 'BCC',
#   'tokens': ['BitConnect', 'BCC']},
#  {'name': 'PotCoin',
#   'rank': 268,
#   'slug': 'potcoin',
#   'symbol': 'POT',
#   'tokens': ['PotCoin', 'POT']},
#  {'name': 'YOYOW',
#   'rank': 269,
#   'slug': 'yoyow',
#   'symbol': 'YOYOW',
#   'tokens': ['YOYOW', 'YOYOW']},
#  {'name': 'Selfkey',
#   'rank': 270,
#   'slug': 'selfkey',
#   'symbol': 'KEY',
#   'tokens': ['Selfkey', 'KEY']},
#  {'name': 'Voxels',
#   'rank': 271,
#   'slug': 'voxels',
#   'symbol': 'VOX',
#   'tokens': ['Voxels', 'VOX']},
#  {'name': 'Blocktix',
#   'rank': 272,
#   'slug': 'blocktix',
#   'symbol': 'TIX',
#   'tokens': ['Blocktix', 'TIX']},
#  {'name': 'Spectrecoin',
#   'rank': 273,
#   'slug': 'spectrecoin',
#   'symbol': 'XSPEC',
#   'tokens': ['Spectrecoin', 'XSPEC']},
#  {'name': 'Lamden',
#   'rank': 274,
#   'slug': 'lamden',
#   'symbol': 'TAU',
#   'tokens': ['Lamden', 'TAU']},
#  {'name': 'Worldcore',
#   'rank': 275,
#   'slug': 'worldcore',
#   'symbol': 'WRC',
#   'tokens': ['Worldcore', 'WRC']},
#  {'name': 'WeTrust',
#   'rank': 276,
#   'slug': 'trust',
#   'symbol': 'TRST',
#   'tokens': ['WeTrust', 'TRST']},
#  {'name': 'Flash',
#   'rank': 277,
#   'slug': 'flash',
#   'symbol': 'FLASH',
#   'tokens': ['Flash', 'FLASH']},
#  {'name': 'Zeusshield',
#   'rank': 278,
#   'slug': 'zeusshield',
#   'symbol': 'ZSC',
#   'tokens': ['Zeusshield', 'ZSC']},
#  {'name': 'Everex',
#   'rank': 279,
#   'slug': 'everex',
#   'symbol': 'EVX',
#   'tokens': ['Everex', 'EVX']},
#  {'name': 'Trade Token',
#   'rank': 280,
#   'slug': 'trade-token',
#   'symbol': 'TIO',
#   'tokens': ['Trade Token', 'TIO']},
#  {'name': 'InsurePal',
#   'rank': 281,
#   'slug': 'insurepal',
#   'symbol': 'IPL',
#   'tokens': ['InsurePal', 'IPL']},
#  {'name': 'SunContract',
#   'rank': 282,
#   'slug': 'suncontract',
#   'symbol': 'SNC',
#   'tokens': ['SunContract', 'SNC']},
#  {'name': 'LATOKEN',
#   'rank': 283,
#   'slug': 'latoken',
#   'symbol': 'LA',
#   'tokens': ['LATOKEN', 'LA']},
#  {'name': 'Olympus Labs',
#   'rank': 284,
#   'slug': 'olympus-labs',
#   'symbol': 'MOT',
#   'tokens': ['Olympus Labs', 'MOT']},
#  {'name': 'PoSW Coin',
#   'rank': 285,
#   'slug': 'posw-coin',
#   'symbol': 'POSW',
#   'tokens': ['PoSW Coin', 'POSW']},
#  {'name': 'Hydro Protocol',
#   'rank': 286,
#   'slug': 'hydro-protocol',
#   'symbol': 'HOT',
#   'tokens': ['Hydro Protocol', 'HOT']},
#  {'name': 'ColossusCoinXT',
#   'rank': 287,
#   'slug': 'colossuscoinxt',
#   'symbol': 'COLX',
#   'tokens': ['ColossusCoinXT', 'COLX']},
#  {'name': 'WhiteCoin',
#   'rank': 288,
#   'slug': 'whitecoin',
#   'symbol': 'XWC',
#   'tokens': ['WhiteCoin', 'XWC']},
#  {'name': 'BitClave',
#   'rank': 289,
#   'slug': 'bitclave',
#   'symbol': 'CAT',
#   'tokens': ['BitClave', 'CAT']},
#  {'name': 'Unobtanium',
#   'rank': 290,
#   'slug': 'unobtanium',
#   'symbol': 'UNO',
#   'tokens': ['Unobtanium', 'UNO']},
#  {'name': 'Bloom',
#   'rank': 291,
#   'slug': 'bloomtoken',
#   'symbol': 'BLT',
#   'tokens': ['Bloom', 'BLT']},
#  {'name': 'iXledger',
#   'rank': 292,
#   'slug': 'ixledger',
#   'symbol': 'IXT',
#   'tokens': ['iXledger', 'IXT']},
#  {'name': 'Numeraire',
#   'rank': 293,
#   'slug': 'numeraire',
#   'symbol': 'NMR',
#   'tokens': ['Numeraire', 'NMR']},
#  {'name': 'Karma',
#   'rank': 294,
#   'slug': 'karma',
#   'symbol': 'KRM',
#   'tokens': ['Karma', 'KRM']},
#  {'name': 'Zeepin',
#   'rank': 295,
#   'slug': 'zeepin',
#   'symbol': 'ZPT',
#   'tokens': ['Zeepin', 'ZPT']},
#  {'name': 'VeriCoin',
#   'rank': 296,
#   'slug': 'vericoin',
#   'symbol': 'VRC',
#   'tokens': ['VeriCoin', 'VRC']},
#  {'name': 'Synereo',
#   'rank': 297,
#   'slug': 'synereo',
#   'symbol': 'AMP',
#   'tokens': ['Synereo', 'AMP']},
#  {'name': 'Elastic',
#   'rank': 298,
#   'slug': 'elastic',
#   'symbol': 'XEL',
#   'tokens': ['Elastic', 'XEL']},
#  {'name': 'FairCoin',
#   'rank': 299,
#   'slug': 'faircoin',
#   'symbol': 'FAIR',
#   'tokens': ['FairCoin', 'FAIR']},
#  {'name': 'Pascal Coin',
#   'rank': 300,
#   'slug': 'pascal-coin',
#   'symbol': 'PASC',
#   'tokens': ['Pascal Coin', 'PASC']},
#  {'name': 'LEOcoin',
#   'rank': 301,
#   'slug': 'leocoin',
#   'symbol': 'LEO',
#   'tokens': ['LEOcoin', 'LEO']},
#  {'name': 'DomRaider',
#   'rank': 302,
#   'slug': 'domraider',
#   'symbol': 'DRT',
#   'tokens': ['DomRaider', 'DRT']},
#  {'name': 'NoLimitCoin',
#   'rank': 303,
#   'slug': 'nolimitcoin',
#   'symbol': 'NLC2',
#   'tokens': ['NoLimitCoin', 'NLC2']},
#  {'name': 'Phore',
#   'rank': 304,
#   'slug': 'phore',
#   'symbol': 'PHR',
#   'tokens': ['Phore', 'PHR']},
#  {'name': 'BlackCoin',
#   'rank': 305,
#   'slug': 'blackcoin',
#   'symbol': 'BLK',
#   'tokens': ['BlackCoin', 'BLK']},
#  {'name': 'Moeda Loyalty Points',
#   'rank': 306,
#   'slug': 'moeda-loyalty-points',
#   'symbol': 'MDA',
#   'tokens': ['Moeda Loyalty Points', 'MDA']},
#  {'name': 'Matchpool',
#   'rank': 307,
#   'slug': 'guppy',
#   'symbol': 'GUP',
#   'tokens': ['Matchpool', 'GUP']},
#  {'name': 'Maecenas',
#   'rank': 308,
#   'slug': 'maecenas',
#   'symbol': 'ART',
#   'tokens': ['Maecenas', 'ART']},
#  {'name': 'Neumark',
#   'rank': 309,
#   'slug': 'neumark',
#   'symbol': 'NEU',
#   'tokens': ['Neumark', 'NEU']},
#  {'name': 'Soarcoin',
#   'rank': 310,
#   'slug': 'soarcoin',
#   'symbol': 'SOAR',
#   'tokens': ['Soarcoin', 'SOAR']},
#  {'name': 'Bean Cash',
#   'rank': 311,
#   'slug': 'bean-cash',
#   'symbol': 'BITB',
#   'tokens': ['Bean Cash', 'BITB']},
#  {'name': 'GridCoin',
#   'rank': 312,
#   'slug': 'gridcoin',
#   'symbol': 'GRC',
#   'tokens': ['GridCoin', 'GRC']},
#  {'name': 'Ormeus Coin',
#   'rank': 313,
#   'slug': 'ormeus-coin',
#   'symbol': 'ORME',
#   'tokens': ['Ormeus Coin', 'ORME']},
#  {'name': 'QunQun',
#   'rank': 314,
#   'slug': 'qunqun',
#   'symbol': 'QUN',
#   'tokens': ['QunQun', 'QUN']},
#  {'name': 'Propy',
#   'rank': 315,
#   'slug': 'propy',
#   'symbol': 'PRO',
#   'tokens': ['Propy', 'PRO']},
#  {'name': 'Bodhi',
#   'rank': 316,
#   'slug': 'bodhi',
#   'symbol': 'BOT',
#   'tokens': ['Bodhi', 'BOT']},
#  {'name': 'Peerplays',
#   'rank': 317,
#   'slug': 'peerplays-ppy',
#   'symbol': 'PPY',
#   'tokens': ['Peerplays', 'PPY']},
#  {'name': 'NVO',
#   'rank': 318,
#   'slug': 'nvo',
#   'symbol': 'NVST',
#   'tokens': ['NVO', 'NVST']},
#  {'name': 'Mothership',
#   'rank': 319,
#   'slug': 'mothership',
#   'symbol': 'MSP',
#   'tokens': ['Mothership', 'MSP']},
#  {'name': 'Open Trading Network',
#   'rank': 320,
#   'slug': 'open-trading-network',
#   'symbol': 'OTN',
#   'tokens': ['Open Trading Network', 'OTN']},
#  {'name': 'CanYaCoin',
#   'rank': 321,
#   'slug': 'canyacoin',
#   'symbol': 'CAN',
#   'tokens': ['CanYaCoin', 'CAN']},
#  {'name': 'SHIELD',
#   'rank': 322,
#   'slug': 'shield-xsh',
#   'symbol': 'XSH',
#   'tokens': ['SHIELD', 'XSH']},
#  {'name': 'Aurora DAO',
#   'rank': 323,
#   'slug': 'aurora-dao',
#   'symbol': 'AURA',
#   'tokens': ['Aurora DAO', 'AURA']},
#  {'name': 'Oxycoin',
#   'rank': 324,
#   'slug': 'oxycoin',
#   'symbol': 'OXY',
#   'tokens': ['Oxycoin', 'OXY']},
#  {'name': 'Universal Currency',
#   'rank': 325,
#   'slug': 'universal-currency',
#   'symbol': 'UNIT',
#   'tokens': ['Universal Currency', 'UNIT']},
#  {'name': 'Expanse',
#   'rank': 326,
#   'slug': 'expanse',
#   'symbol': 'EXP',
#   'tokens': ['Expanse', 'EXP']},
#  {'name': 'Mintcoin',
#   'rank': 327,
#   'slug': 'mintcoin',
#   'symbol': 'MINT',
#   'tokens': ['Mintcoin', 'MINT']},
#  {'name': 'BlockMason Credit Protocol',
#   'rank': 328,
#   'slug': 'blockmason',
#   'symbol': 'BCPT',
#   'tokens': ['BlockMason Credit Protocol', 'BCPT']},
#  {'name': 'HelloGold',
#   'rank': 329,
#   'slug': 'hellogold',
#   'symbol': 'HGT',
#   'tokens': ['HelloGold', 'HGT']},
#  {'name': 'Unity Ingot',
#   'rank': 330,
#   'slug': 'unity-ingot',
#   'symbol': 'UNY',
#   'tokens': ['Unity Ingot', 'UNY']},
#  {'name': 'MyBit Token',
#   'rank': 331,
#   'slug': 'mybit-token',
#   'symbol': 'MYB',
#   'tokens': ['MyBit Token', 'MYB']},
#  {'name': 'Swarm City',
#   'rank': 332,
#   'slug': 'swarm-city',
#   'symbol': 'SWT',
#   'tokens': ['Swarm City', 'SWT']},
#  {'name': 'Omni',
#   'rank': 333,
#   'slug': 'omni',
#   'symbol': 'OMNI',
#   'tokens': ['Omni', 'OMNI']},
#  {'name': 'Snovio',
#   'rank': 334,
#   'slug': 'snovio',
#   'symbol': 'SNOV',
#   'tokens': ['Snovio', 'SNOV']},
#  {'name': 'Aeron',
#   'rank': 335,
#   'slug': 'aeron',
#   'symbol': 'ARN',
#   'tokens': ['Aeron', 'ARN']},
#  {'name': 'OAX',
#   'rank': 336,
#   'slug': 'oax',
#   'symbol': 'OAX',
#   'tokens': ['OAX', 'OAX']},
#  {'name': 'MonetaryUnit',
#   'rank': 337,
#   'slug': 'monetaryunit',
#   'symbol': 'MUE',
#   'tokens': ['MonetaryUnit', 'MUE']},
#  {'name': 'NewYorkCoin',
#   'rank': 338,
#   'slug': 'newyorkcoin',
#   'symbol': 'NYC',
#   'tokens': ['NewYorkCoin', 'NYC']},
#  {'name': 'Radium',
#   'rank': 339,
#   'slug': 'radium',
#   'symbol': 'RADS',
#   'tokens': ['Radium', 'RADS']},
#  {'name': 'Zoin',
#   'rank': 340,
#   'slug': 'zoin',
#   'symbol': 'ZOI',
#   'tokens': ['Zoin', 'ZOI']},
#  {'name': 'Uquid Coin',
#   'rank': 341,
#   'slug': 'uquid-coin',
#   'symbol': 'UQC',
#   'tokens': ['Uquid Coin', 'UQC']},
#  {'name': 'Golos',
#   'rank': 342,
#   'slug': 'golos',
#   'symbol': 'GOLOS',
#   'tokens': ['Golos', 'GOLOS']},
#  {'name': 'ICOS',
#   'rank': 343,
#   'slug': 'icos',
#   'symbol': 'ICOS',
#   'tokens': ['ICOS', 'ICOS']},
#  {'name': 'Rubycoin',
#   'rank': 344,
#   'slug': 'rubycoin',
#   'symbol': 'RBY',
#   'tokens': ['Rubycoin', 'RBY']},
#  {'name': 'E-coin',
#   'rank': 345,
#   'slug': 'e-coin',
#   'symbol': 'ECN',
#   'tokens': ['E-coin', 'ECN']},
#  {'name': 'Boolberry',
#   'rank': 346,
#   'slug': 'boolberry',
#   'symbol': 'BBR',
#   'tokens': ['Boolberry', 'BBR']},
#  {'name': 'OKCash',
#   'rank': 347,
#   'slug': 'okcash',
#   'symbol': 'OK',
#   'tokens': ['OKCash', 'OK']},
#  {'name': 'Jesus Coin',
#   'rank': 348,
#   'slug': 'jesus-coin',
#   'symbol': 'JC',
#   'tokens': ['Jesus Coin', 'JC']},
#  {'name': 'SolarCoin',
#   'rank': 349,
#   'slug': 'solarcoin',
#   'symbol': 'SLR',
#   'tokens': ['SolarCoin', 'SLR']},
#  {'name': 'KickCoin',
#   'rank': 350,
#   'slug': 'kickico',
#   'symbol': 'KICK',
#   'tokens': ['KickCoin', 'KICK']},
#  {'name': 'Waves Community Token',
#   'rank': 351,
#   'slug': 'waves-community-token',
#   'symbol': 'WCT',
#   'tokens': ['Waves Community Token', 'WCT']},
#  {'name': 'EncrypGen',
#   'rank': 352,
#   'slug': 'encrypgen',
#   'symbol': 'DNA',
#   'tokens': ['EncrypGen', 'DNA']},
#  {'name': 'Stox',
#   'rank': 353,
#   'slug': 'stox',
#   'symbol': 'STX',
#   'tokens': ['Stox', 'STX']},
#  {'name': 'CoinMeet',
#   'rank': 354,
#   'slug': 'coinmeet',
#   'symbol': 'MEE',
#   'tokens': ['CoinMeet', 'MEE']},
#  {'name': 'Playkey',
#   'rank': 355,
#   'slug': 'playkey',
#   'symbol': 'PKT',
#   'tokens': ['Playkey', 'PKT']},
#  {'name': 'Myriad',
#   'rank': 356,
#   'slug': 'myriad',
#   'symbol': 'XMY',
#   'tokens': ['Myriad', 'XMY']},
#  {'name': 'E-Dinar Coin',
#   'rank': 357,
#   'slug': 'e-dinar-coin',
#   'symbol': 'EDR',
#   'tokens': ['E-Dinar Coin', 'EDR']},
#  {'name': 'Covesting',
#   'rank': 358,
#   'slug': 'covesting',
#   'symbol': 'COV',
#   'tokens': ['Covesting', 'COV']},
#  {'name': 'OracleChain',
#   'rank': 359,
#   'slug': 'oraclechain',
#   'symbol': 'OCT',
#   'tokens': ['OracleChain', 'OCT']},
#  {'name': 'Energycoin',
#   'rank': 360,
#   'slug': 'energycoin',
#   'symbol': 'ENRG',
#   'tokens': ['Energycoin', 'ENRG']},
#  {'name': 'ProChain',
#   'rank': 361,
#   'slug': 'prochain',
#   'symbol': 'PRA',
#   'tokens': ['ProChain', 'PRA']},
#  {'name': 'Voise',
#   'rank': 362,
#   'slug': 'voisecom',
#   'symbol': 'VOISE',
#   'tokens': ['Voise', 'VOISE']},
#  {'name': 'BitSend',
#   'rank': 363,
#   'slug': 'bitsend',
#   'symbol': 'BSD',
#   'tokens': ['BitSend', 'BSD']},
#  {'name': 'Bounty0x',
#   'rank': 364,
#   'slug': 'bounty0x',
#   'symbol': 'BNTY',
#   'tokens': ['Bounty0x', 'BNTY']},
#  {'name': 'Clams',
#   'rank': 365,
#   'slug': 'clams',
#   'symbol': 'CLAM',
#   'tokens': ['Clams', 'CLAM']},
#  {'name': 'Hackspace Capital',
#   'rank': 366,
#   'slug': 'hackspace-capital',
#   'symbol': 'HAC',
#   'tokens': ['Hackspace Capital', 'HAC']},
#  {'name': 'Primecoin',
#   'rank': 367,
#   'slug': 'primecoin',
#   'symbol': 'XPM',
#   'tokens': ['Primecoin', 'XPM']},
#  {'name': 'GoByte',
#   'rank': 368,
#   'slug': 'gobyte',
#   'symbol': 'GBX',
#   'tokens': ['GoByte', 'GBX']},
#  {'name': 'Pandacoin',
#   'rank': 369,
#   'slug': 'pandacoin-pnd',
#   'symbol': 'PND',
#   'tokens': ['Pandacoin', 'PND']},
#  {'name': 'Polybius',
#   'rank': 370,
#   'slug': 'polybius',
#   'symbol': 'PLBT',
#   'tokens': ['Polybius', 'PLBT']},
#  {'name': 'ATBCoin',
#   'rank': 371,
#   'slug': 'atbcoin',
#   'symbol': 'ATB',
#   'tokens': ['ATBCoin', 'ATB']},
#  {'name': 'AirToken',
#   'rank': 372,
#   'slug': 'airtoken',
#   'symbol': 'AIR',
#   'tokens': ['AirToken', 'AIR']},
#  {'name': 'Primas',
#   'rank': 373,
#   'slug': 'primas',
#   'symbol': 'PST',
#   'tokens': ['Primas', 'PST']},
#  {'name': 'Profile Utility Token',
#   'rank': 374,
#   'slug': 'profile-utility-token',
#   'symbol': 'PUT',
#   'tokens': ['Profile Utility Token', 'PUT']},
#  {'name': 'DecentBet',
#   'rank': 375,
#   'slug': 'decent-bet',
#   'symbol': 'DBET',
#   'tokens': ['DecentBet', 'DBET']},
#  {'name': 'ALIS',
#   'rank': 376,
#   'slug': 'alis',
#   'symbol': 'ALIS',
#   'tokens': ['ALIS', 'ALIS']},
#  {'name': 'Target Coin',
#   'rank': 377,
#   'slug': 'target-coin',
#   'symbol': 'TGT',
#   'tokens': ['Target Coin', 'TGT']},
#  {'name': 'LoMoCoin',
#   'rank': 378,
#   'slug': 'lomocoin',
#   'symbol': 'LMC',
#   'tokens': ['LoMoCoin', 'LMC']},
#  {'name': 'Hacken',
#   'rank': 379,
#   'slug': 'hacken',
#   'symbol': 'HKN',
#   'tokens': ['Hacken', 'HKN']},
#  {'name': 'Nexium',
#   'rank': 380,
#   'slug': 'nexium',
#   'symbol': 'NXC',
#   'tokens': ['Nexium', 'NXC']},
#  {'name': 'Etheroll',
#   'rank': 381,
#   'slug': 'etheroll',
#   'symbol': 'DICE',
#   'tokens': ['Etheroll', 'DICE']},
#  {'name': 'Auroracoin',
#   'rank': 382,
#   'slug': 'auroracoin',
#   'symbol': 'AUR',
#   'tokens': ['Auroracoin', 'AUR']},
#  {'name': 'Linda',
#   'rank': 383,
#   'slug': 'linda',
#   'symbol': 'LINDA',
#   'tokens': ['Linda', 'LINDA']},
#  {'name': 'Blackmoon',
#   'rank': 384,
#   'slug': 'blackmoon',
#   'symbol': 'BMC',
#   'tokens': ['Blackmoon', 'BMC']},
#  {'name': 'ClearPoll',
#   'rank': 385,
#   'slug': 'clearpoll',
#   'symbol': 'POLL',
#   'tokens': ['ClearPoll', 'POLL']},
#  {'name': 'Neutron',
#   'rank': 386,
#   'slug': 'neutron',
#   'symbol': 'NTRN',
#   'tokens': ['Neutron', 'NTRN']},
#  {'name': 'BitDice',
#   'rank': 387,
#   'slug': 'bitdice',
#   'symbol': 'CSNO',
#   'tokens': ['BitDice', 'CSNO']},
#  {'name': 'OneRoot Network',
#   'rank': 388,
#   'slug': 'oneroot-network',
#   'symbol': 'RNT',
#   'tokens': ['OneRoot Network', 'RNT']},
#  {'name': 'DubaiCoin',
#   'rank': 389,
#   'slug': 'dubaicoin-dbix',
#   'symbol': 'DBIX',
#   'tokens': ['DubaiCoin', 'DBIX']},
#  {'name': 'Xaurum',
#   'rank': 390,
#   'slug': 'xaurum',
#   'symbol': 'XAUR',
#   'tokens': ['Xaurum', 'XAUR']},
#  {'name': 'Quantum',
#   'rank': 391,
#   'slug': 'quantum',
#   'symbol': 'QAU',
#   'tokens': ['Quantum', 'QAU']},
#  {'name': 'NeosCoin',
#   'rank': 392,
#   'slug': 'neoscoin',
#   'symbol': 'NEOS',
#   'tokens': ['NeosCoin', 'NEOS']},
#  {'name': 'Rialto',
#   'rank': 393,
#   'slug': 'rialto',
#   'symbol': 'XRL',
#   'tokens': ['Rialto', 'XRL']},
#  {'name': 'Blockport',
#   'rank': 394,
#   'slug': 'blockport',
#   'symbol': 'BPT',
#   'tokens': ['Blockport', 'BPT']},
#  {'name': 'Paragon',
#   'rank': 395,
#   'slug': 'paragon',
#   'symbol': 'PRG',
#   'tokens': ['Paragon', 'PRG']},
#  {'name': 'Circuits of Value',
#   'rank': 396,
#   'slug': 'circuits-of-value',
#   'symbol': 'COVAL',
#   'tokens': ['Circuits of Value', 'COVAL']},
#  {'name': 'bitUSD',
#   'rank': 397,
#   'slug': 'bitusd',
#   'symbol': 'BITUSD',
#   'tokens': ['bitUSD', 'BITUSD']},
#  {'name': 'BLUE',
#   'rank': 398,
#   'slug': 'ethereum-blue',
#   'symbol': 'BLUE',
#   'tokens': ['BLUE', 'BLUE']},
#  {'name': 'FlorinCoin',
#   'rank': 399,
#   'slug': 'florincoin',
#   'symbol': 'FLO',
#   'tokens': ['FlorinCoin', 'FLO']},
#  {'name': 'Hedge',
#   'rank': 400,
#   'slug': 'hedge',
#   'symbol': 'HDG',
#   'tokens': ['Hedge', 'HDG']},
#  {'name': 'FoldingCoin',
#   'rank': 401,
#   'slug': 'foldingcoin',
#   'symbol': 'FLDC',
#   'tokens': ['FoldingCoin', 'FLDC']},
#  {'name': 'Viuly',
#   'rank': 402,
#   'slug': 'viuly',
#   'symbol': 'VIU',
#   'tokens': ['Viuly', 'VIU']},
#  {'name': 'SportyCo',
#   'rank': 403,
#   'slug': 'sportyco',
#   'symbol': 'SPF',
#   'tokens': ['SportyCo', 'SPF']},
#  {'name': 'Gambit',
#   'rank': 404,
#   'slug': 'gambit',
#   'symbol': 'GAM',
#   'tokens': ['Gambit', 'GAM']},
#  {'name': 'eBitcoin',
#   'rank': 405,
#   'slug': 'ebtcnew',
#   'symbol': 'EBTC',
#   'tokens': ['eBitcoin', 'EBTC']},
#  {'name': 'Dai',
#   'rank': 406,
#   'slug': 'dai',
#   'symbol': 'DAI',
#   'tokens': ['Dai', 'DAI']},
#  {'name': 'Chronobank',
#   'rank': 407,
#   'slug': 'chronobank',
#   'symbol': 'TIME',
#   'tokens': ['Chronobank', 'TIME']},
#  {'name': 'Exchange Union',
#   'rank': 408,
#   'slug': 'exchange-union',
#   'symbol': 'XUC',
#   'tokens': ['Exchange Union', 'XUC']},
#  {'name': 'Databits',
#   'rank': 409,
#   'slug': 'databits',
#   'symbol': 'DTB',
#   'tokens': ['Databits', 'DTB']},
#  {'name': 'Syndicate',
#   'rank': 410,
#   'slug': 'syndicate',
#   'symbol': 'SYNX',
#   'tokens': ['Syndicate', 'SYNX']},
#  {'name': 'LUXCoin',
#   'rank': 411,
#   'slug': 'luxcoin',
#   'symbol': 'LUX',
#   'tokens': ['LUXCoin', 'LUX']},
#  {'name': 'Patientory',
#   'rank': 412,
#   'slug': 'patientory',
#   'symbol': 'PTOY',
#   'tokens': ['Patientory', 'PTOY']},
#  {'name': 'Russian Miner Coin',
#   'rank': 413,
#   'slug': 'russian-mining-coin',
#   'symbol': 'RMC',
#   'tokens': ['Russian Miner Coin', 'RMC']},
#  {'name': 'Mysterium',
#   'rank': 414,
#   'slug': 'mysterium',
#   'symbol': 'MYST',
#   'tokens': ['Mysterium', 'MYST']},
#  {'name': 'NuBits',
#   'rank': 415,
#   'slug': 'nubits',
#   'symbol': 'USNBT',
#   'tokens': ['NuBits', 'USNBT']},
#  {'name': 'Aventus',
#   'rank': 416,
#   'slug': 'aventus',
#   'symbol': 'AVT',
#   'tokens': ['Aventus', 'AVT']},
#  {'name': 'InvestFeed',
#   'rank': 417,
#   'slug': 'investfeed',
#   'symbol': 'IFT',
#   'tokens': ['InvestFeed', 'IFT']},
#  {'name': 'LockChain',
#   'rank': 418,
#   'slug': 'lockchain',
#   'symbol': 'LOC',
#   'tokens': ['LockChain', 'LOC']},
#  {'name': 'Ethorse',
#   'rank': 419,
#   'slug': 'ethorse',
#   'symbol': 'HORSE',
#   'tokens': ['Ethorse', 'HORSE']},
#  {'name': 'PRIZM',
#   'rank': 420,
#   'slug': 'prizm',
#   'symbol': 'PZM',
#   'tokens': ['PRIZM', 'PZM']},
#  {'name': 'LIFE',
#   'rank': 421,
#   'slug': 'life',
#   'symbol': 'LIFE',
#   'tokens': ['LIFE', 'LIFE']},
#  {'name': 'bitqy',
#   'rank': 422,
#   'slug': 'bitqy',
#   'symbol': 'BQ',
#   'tokens': ['bitqy', 'BQ']},
#  {'name': 'Bitcrystals',
#   'rank': 423,
#   'slug': 'bitcrystals',
#   'symbol': 'BCY',
#   'tokens': ['Bitcrystals', 'BCY']},
#  {'name': 'NuShares',
#   'rank': 424,
#   'slug': 'nushares',
#   'symbol': 'NSR',
#   'tokens': ['NuShares', 'NSR']},
#  {'name': 'Incent',
# ...
#   'rank': 865,
#   'slug': 'parallelcoin',
#   'symbol': 'DUO',
#   'tokens': ['ParallelCoin', 'DUO']},
#  {'name': 'LiteBitcoin',
#   'rank': 866,
#   'slug': 'litebitcoin',
#   'symbol': 'LBTC',
#   'tokens': ['LiteBitcoin', 'LBTC']},
#  {'name': 'Darsek',
#   'rank': 867,
#   'slug': 'darsek',
#   'symbol': 'KED',
#   'tokens': ['Darsek', 'KED']},
#  {'name': 'Mao Zedong',
#   'rank': 868,
#   'slug': 'mao-zedong',
#   'symbol': 'MAO',
#   'tokens': ['Mao Zedong', 'MAO']},
#  {'name': 'Quatloo',
#   'rank': 869,
#   'slug': 'quatloo',
#   'symbol': 'QTL',
#   'tokens': ['Quatloo', 'QTL']},
#  {'name': 'Zurcoin',
#   'rank': 870,
#   'slug': 'zurcoin',
#   'symbol': 'ZUR',
#   'tokens': ['Zurcoin', 'ZUR']},
#  {'name': 'Honey',
#   'rank': 871,
#   'slug': 'honey',
#   'symbol': 'HONEY',
#   'tokens': ['Honey', 'HONEY']},
#  {'name': 'MustangCoin',
#   'rank': 872,
#   'slug': 'mustangcoin',
#   'symbol': 'MST',
#   'tokens': ['MustangCoin', 'MST']},
#  {'name': 'DIBCOIN',
#   'rank': 873,
#   'slug': 'dibcoin',
#   'symbol': 'DIBC',
#   'tokens': ['DIBCOIN', 'DIBC']},
#  {'name': 'Dalecoin',
#   'rank': 874,
#   'slug': 'dalecoin',
#   'symbol': 'DALC',
#   'tokens': ['Dalecoin', 'DALC']},
#  {'name': 'ICOBID',
#   'rank': 875,
#   'slug': 'icobid',
#   'symbol': 'ICOB',
#   'tokens': ['ICOBID', 'ICOB']},
#  {'name': 'Global Tour Coin',
#   'rank': 876,
#   'slug': 'global-tour-coin',
#   'symbol': 'GTC',
#   'tokens': ['Global Tour Coin', 'GTC']},
#  {'name': 'Veltor',
#   'rank': 877,
#   'slug': 'veltor',
#   'symbol': 'VLT',
#   'tokens': ['Veltor', 'VLT']},
#  {'name': 'PayCon',
#   'rank': 878,
#   'slug': 'paycon',
#   'symbol': 'CON',
#   'tokens': ['PayCon', 'CON']},
#  {'name': 'Roofs',
#   'rank': 879,
#   'slug': 'roofs',
#   'symbol': 'ROOFS',
#   'tokens': ['Roofs', 'ROOFS']},
#  {'name': 'Bolenum',
#   'rank': 880,
#   'slug': 'bolenum',
#   'symbol': 'BLN',
#   'tokens': ['Bolenum', 'BLN']},
#  {'name': 'Quebecoin',
#   'rank': 881,
#   'slug': 'quebecoin',
#   'symbol': 'QBC',
#   'tokens': ['Quebecoin', 'QBC']},
#  {'name': 'Iconic',
#   'rank': 882,
#   'slug': 'iconic',
#   'symbol': 'ICON',
#   'tokens': ['Iconic', 'ICON']},
#  {'name': 'Marijuanacoin',
#   'rank': 883,
#   'slug': 'marijuanacoin',
#   'symbol': 'MAR',
#   'tokens': ['Marijuanacoin', 'MAR']},
#  {'name': 'Cannation',
#   'rank': 884,
#   'slug': 'cannation',
#   'symbol': 'CNNC',
#   'tokens': ['Cannation', 'CNNC']},
#  {'name': 'CompuCoin',
#   'rank': 885,
#   'slug': 'compucoin',
#   'symbol': 'CPN',
#   'tokens': ['CompuCoin', 'CPN']},
#  {'name': 'FuzzBalls',
#   'rank': 886,
#   'slug': 'fuzzballs',
#   'symbol': 'FUZZ',
#   'tokens': ['FuzzBalls', 'FUZZ']},
#  {'name': 'EcoCoin',
#   'rank': 887,
#   'slug': 'ecocoin',
#   'symbol': 'ECO',
#   'tokens': ['EcoCoin', 'ECO']},
#  {'name': 'iDice',
#   'rank': 888,
#   'slug': 'idice',
#   'symbol': 'ICE',
#   'tokens': ['iDice', 'ICE']},
#  {'name': 'Beatcoin',
#   'rank': 889,
#   'slug': 'beatcoin',
#   'symbol': 'XBTS',
#   'tokens': ['Beatcoin', 'XBTS']},
#  {'name': 'Evotion',
#   'rank': 890,
#   'slug': 'evotion',
#   'symbol': 'EVO',
#   'tokens': ['Evotion', 'EVO']},
#  {'name': 'CacheCoin',
#   'rank': 891,
#   'slug': 'cachecoin',
#   'symbol': 'CACH',
#   'tokens': ['CacheCoin', 'CACH']},
#  {'name': 'GoldPieces',
#   'rank': 892,
#   'slug': 'goldpieces',
#   'symbol': 'GP',
#   'tokens': ['GoldPieces', 'GP']},
#  {'name': 'BipCoin',
#   'rank': 893,
#   'slug': 'bipcoin',
#   'symbol': 'BIP',
#   'tokens': ['BipCoin', 'BIP']},
#  {'name': 'Eryllium',
#   'rank': 894,
#   'slug': 'eryllium',
#   'symbol': 'ERY',
#   'tokens': ['Eryllium', 'ERY']},
#  {'name': 'EagleCoin',
#   'rank': 895,
#   'slug': 'eaglecoin',
#   'symbol': 'EAGLE',
#   'tokens': ['EagleCoin', 'EAGLE']},
#  {'name': 'X-Coin',
#   'rank': 896,
#   'slug': 'x-coin',
#   'symbol': 'XCO',
#   'tokens': ['X-Coin', 'XCO']},
#  {'name': 'Comet',
#   'rank': 897,
#   'slug': 'comet',
#   'symbol': 'CMT',
#   'tokens': ['Comet', 'CMT']},
#  {'name': 'Useless Ethereum Token',
#   'rank': 898,
#   'slug': 'useless-ethereum-token',
#   'symbol': 'UET',
#   'tokens': ['Useless Ethereum Token', 'UET']},
#  {'name': 'Gold Pressed Latinum',
#   'rank': 899,
#   'slug': 'gold-pressed-latinum',
#   'symbol': 'GPL',
#   'tokens': ['Gold Pressed Latinum', 'GPL']},
#  {'name': 'Bitcedi',
#   'rank': 900,
#   'slug': 'bitcedi',
#   'symbol': 'BXC',
#   'tokens': ['Bitcedi', 'BXC']},
#  {'name': 'Spots',
#   'rank': 901,
#   'slug': 'spots',
#   'symbol': 'SPT',
#   'tokens': ['Spots', 'SPT']},
#  {'name': 'SongCoin',
#   'rank': 902,
#   'slug': 'songcoin',
#   'symbol': 'SONG',
#   'tokens': ['SongCoin', 'SONG']},
#  {'name': 'Allion',
#   'rank': 903,
#   'slug': 'allion',
#   'symbol': 'ALL',
#   'tokens': ['Allion', 'ALL']},
#  {'name': 'Money',
#   'rank': 904,
#   'slug': 'money',
#   'symbol': '$$$',
#   'tokens': ['Money', '$$$']},
#  {'name': 'Cthulhu Offerings',
#   'rank': 905,
#   'slug': 'cthulhu-offerings',
#   'symbol': 'OFF',
#   'tokens': ['Cthulhu Offerings', 'OFF']},
#  {'name': 'Master Swiscoin',
#   'rank': 906,
#   'slug': 'master-swiscoin',
#   'symbol': 'MSCN',
#   'tokens': ['Master Swiscoin', 'MSCN']},
#  {'name': 'bitEUR',
#   'rank': 907,
#   'slug': 'biteur',
#   'symbol': 'BITEUR',
#   'tokens': ['bitEUR', 'BITEUR']},
#  {'name': 'VapersCoin',
#   'rank': 908,
#   'slug': 'vaperscoin',
#   'symbol': 'VPRC',
#   'tokens': ['VapersCoin', 'VPRC']},
#  {'name': 'Debitcoin',
#   'rank': 909,
#   'slug': 'debitcoin',
#   'symbol': 'DBTC',
#   'tokens': ['Debitcoin', 'DBTC']},
#  {'name': 'Coinonat',
#   'rank': 910,
#   'slug': 'coinonat',
#   'symbol': 'CXT',
#   'tokens': ['Coinonat', 'CXT']},
#  {'name': 'BenjiRolls',
#   'rank': 911,
#   'slug': 'benjirolls',
#   'symbol': 'BENJI',
#   'tokens': ['BenjiRolls', 'BENJI']},
#  {'name': 'Firecoin',
#   'rank': 912,
#   'slug': 'firecoin',
#   'symbol': 'FIRE',
#   'tokens': ['Firecoin', 'FIRE']},
#  {'name': 'Solarflarecoin',
#   'rank': 913,
#   'slug': 'solarflarecoin',
#   'symbol': 'SFC',
#   'tokens': ['Solarflarecoin', 'SFC']},
#  {'name': 'Kronecoin',
#   'rank': 914,
#   'slug': 'kronecoin',
#   'symbol': 'KRONE',
#   'tokens': ['Kronecoin', 'KRONE']},
#  {'name': 'ZetaMicron',
#   'rank': 915,
#   'slug': 'zetamicron',
#   'symbol': 'ZMC',
#   'tokens': ['ZetaMicron', 'ZMC']},
#  {'name': 'LiteCoin Ultra',
#   'rank': 916,
#   'slug': 'litecoin-ultra',
#   'symbol': 'LTCU',
#   'tokens': ['LiteCoin Ultra', 'LTCU']},
#  {'name': 'ExchangeN',
#   'rank': 917,
#   'slug': 'exchangen',
#   'symbol': 'EXN',
#   'tokens': ['ExchangeN', 'EXN']},
#  {'name': 'JobsCoin',
#   'rank': 918,
#   'slug': 'jobscoin',
#   'symbol': 'JOBS',
#   'tokens': ['JobsCoin', 'JOBS']},
#  {'name': 'BOAT',
#   'rank': 919,
#   'slug': 'doubloon',
#   'symbol': 'BOAT',
#   'tokens': ['BOAT', 'BOAT']},
#  {'name': 'Tychocoin',
#   'rank': 920,
#   'slug': 'tychocoin',
#   'symbol': 'TYCHO',
#   'tokens': ['Tychocoin', 'TYCHO']},
#  {'name': 'Artex Coin',
#   'rank': 921,
#   'slug': 'artex-coin',
#   'symbol': 'ATX',
#   'tokens': ['Artex Coin', 'ATX']},
#  {'name': 'Bitvolt',
#   'rank': 922,
#   'slug': 'bitvolt',
#   'symbol': 'VOLT',
#   'tokens': ['Bitvolt', 'VOLT']},
#  {'name': 'Litecred',
#   'rank': 923,
#   'slug': 'litecred',
#   'symbol': 'LTCR',
#   'tokens': ['Litecred', 'LTCR']},
#  {'name': 'GeertCoin',
#   'rank': 924,
#   'slug': 'geertcoin',
#   'symbol': 'GEERT',
#   'tokens': ['GeertCoin', 'GEERT']},
#  {'name': 'WomenCoin',
#   'rank': 925,
#   'slug': 'women',
#   'symbol': 'WOMEN',
#   'tokens': ['WomenCoin', 'WOMEN']},
#  {'name': 'Credence Coin',
#   'rank': 926,
#   'slug': 'credence-coin',
#   'symbol': 'CRDNC',
#   'tokens': ['Credence Coin', 'CRDNC']},
#  {'name': 'Xonecoin',
#   'rank': 927,
#   'slug': 'xonecoin',
#   'symbol': 'XOC',
#   'tokens': ['Xonecoin', 'XOC']},
#  {'name': 'Dollar Online',
#   'rank': 928,
#   'slug': 'dollar-online',
#   'symbol': 'DOLLAR',
#   'tokens': ['Dollar Online', 'DOLLAR']},
#  {'name': 'Veros',
#   'rank': 929,
#   'slug': 'veros',
#   'symbol': 'VRS',
#   'tokens': ['Veros', 'VRS']},
#  {'name': 'Coupecoin',
#   'rank': 930,
#   'slug': 'coupecoin',
#   'symbol': 'COUPE',
#   'tokens': ['Coupecoin', 'COUPE']},
#  {'name': 'PRCoin',
#   'rank': 931,
#   'slug': 'prcoin',
#   'symbol': 'PRC',
#   'tokens': ['PRCoin', 'PRC']},
#  {'name': 'Coimatic 3.0',
#   'rank': 932,
#   'slug': 'coimatic-3',
#   'symbol': 'CTIC3',
#   'tokens': ['Coimatic 3.0', 'CTIC3']},
#  {'name': 'Project-X',
#   'rank': 933,
#   'slug': 'project-x',
#   'symbol': 'NANOX',
#   'tokens': ['Project-X', 'NANOX']},
#  {'name': 'CrevaCoin',
#   'rank': 934,
#   'slug': 'crevacoin',
#   'symbol': 'CREVA',
#   'tokens': ['CrevaCoin', 'CREVA']},
#  {'name': 'FuturXe',
#   'rank': 935,
#   'slug': 'futurexe',
#   'symbol': 'FXE',
#   'tokens': ['FuturXe', 'FXE']},
#  {'name': 'Aerium',
#   'rank': 936,
#   'slug': 'aerium',
#   'symbol': 'AERM',
#   'tokens': ['Aerium', 'AERM']},
#  {'name': 'Vault Coin',
#   'rank': 937,
#   'slug': 'vault-coin',
#   'symbol': 'VLTC',
#   'tokens': ['Vault Coin', 'VLTC']},
#  {'name': 'Magnum',
#   'rank': 938,
#   'slug': 'magnum',
#   'symbol': 'MGM',
#   'tokens': ['Magnum', 'MGM']},
#  {'name': 'LevoPlus',
#   'rank': 939,
#   'slug': 'levoplus',
#   'symbol': 'LVPS',
#   'tokens': ['LevoPlus', 'LVPS']},
#  {'name': 'EXRNchain',
#   'rank': 940,
#   'slug': 'exrnchain',
#   'symbol': 'EXRN',
#   'tokens': ['EXRNchain', 'EXRN']},
#  {'name': 'Tristar Coin',
#   'rank': 941,
#   'slug': 'tristar-coin',
#   'symbol': 'TSTR',
#   'tokens': ['Tristar Coin', 'TSTR']},
#  {'name': 'HarmonyCoin',
#   'rank': 942,
#   'slug': 'harmonycoin-hmc',
#   'symbol': 'HMC',
#   'tokens': ['HarmonyCoin', 'HMC']},
#  {'name': 'PizzaCoin',
#   'rank': 943,
#   'slug': 'pizzacoin',
#   'symbol': 'PIZZA',
#   'tokens': ['PizzaCoin', 'PIZZA']},
#  {'name': 'Abncoin',
#   'rank': 944,
#   'slug': 'abncoin',
#   'symbol': 'ABN',
#   'tokens': ['Abncoin', 'ABN']},
#  {'name': 'Paypex',
#   'rank': 945,
#   'slug': 'paypex',
#   'symbol': 'PAYX',
#   'tokens': ['Paypex', 'PAYX']},
#  {'name': 'Jinn',
#   'rank': 946,
#   'slug': 'jinn',
#   'symbol': 'JINN',
#   'tokens': ['Jinn', 'JINN']},
#  {'name': 'Grid+',
#   'rank': 947,
#   'slug': 'grid',
#   'symbol': 'GRID',
#   'tokens': ['Grid+', 'GRID']},
#  {'name': 'Spectre.ai Dividend Token',
#   'rank': 948,
#   'slug': 'spectre-dividend',
#   'symbol': 'SXDT',
#   'tokens': ['Spectre.ai Dividend Token', 'SXDT']},
#  {'name': 'BCAP',
#   'rank': 949,
#   'slug': 'bcap',
#   'symbol': 'BCAP',
#   'tokens': ['BCAP', 'BCAP']},
#  {'name': 'PlusCoin',
#   'rank': 950,
#   'slug': 'pluscoin',
#   'symbol': 'PLC',
#   'tokens': ['PlusCoin', 'PLC']},
#  {'name': 'Starbase',
#   'rank': 951,
#   'slug': 'starbase',
#   'symbol': 'STAR',
#   'tokens': ['Starbase', 'STAR']},
#  {'name': 'Hubii Network',
#   'rank': 952,
#   'slug': 'hubii-network',
#   'symbol': 'HBT',
#   'tokens': ['Hubii Network', 'HBT']},
#  {'name': 'Xenon',
#   'rank': 953,
#   'slug': 'xenon',
#   'symbol': 'XNN',
#   'tokens': ['Xenon', 'XNN']},
#  {'name': 'REX',
#   'rank': 954,
#   'slug': 'real-estate-tokens',
#   'symbol': 'REX',
#   'tokens': ['REX', 'REX']},
#  {'name': 'Mercury Protocol',
#   'rank': 955,
#   'slug': 'mercury-protocol',
#   'symbol': 'GMT',
#   'tokens': ['Mercury Protocol', 'GMT']},
#  {'name': 'Prospectors Gold',
#   'rank': 956,
#   'slug': 'prospectors-gold',
#   'symbol': 'PGL',
#   'tokens': ['Prospectors Gold', 'PGL']},
#  {'name': 'Astro',
#   'rank': 957,
#   'slug': 'astro',
#   'symbol': 'ASTRO',
#   'tokens': ['Astro', 'ASTRO']},
#  {'name': 'Credo',
#   'rank': 958,
#   'slug': 'credo',
#   'symbol': 'CREDO',
#   'tokens': ['Credo', 'CREDO']},
#  {'name': 'Virtacoin',
#   'rank': 959,
#   'slug': 'virtacoin',
#   'symbol': 'VTA',
#   'tokens': ['Virtacoin', 'VTA']},
#  {'name': 'REAL',
#   'rank': 960,
#   'slug': 'real',
#   'symbol': 'REAL',
#   'tokens': ['REAL', 'REAL']},
#  {'name': 'SmartBillions',
#   'rank': 961,
#   'slug': 'smartbillions',
#   'symbol': 'SMART',
#   'tokens': ['SmartBillions', 'SMART']},
#  {'name': 'Goodomy',
#   'rank': 962,
#   'slug': 'goodomy',
#   'symbol': 'GOOD',
#   'tokens': ['Goodomy', 'GOOD']},
#  {'name': 'EncryptoTel [WAVES]',
#   'rank': 963,
#   'slug': 'encryptotel',
#   'symbol': 'ETT',
#   'tokens': ['EncryptoTel [WAVES]', 'ETT']},
#  {'name': 'Privatix',
#   'rank': 964,
#   'slug': 'privatix',
#   'symbol': 'PRIX',
#   'tokens': ['Privatix', 'PRIX']},
#  {'name': 'LuckChain',
#   'rank': 965,
#   'slug': 'luckchain',
#   'symbol': 'BASH',
#   'tokens': ['LuckChain', 'BASH']},
#  {'name': 'Crypto Bullion',
#   'rank': 966,
#   'slug': 'cryptogenic-bullion',
#   'symbol': 'CBX',
#   'tokens': ['Crypto Bullion', 'CBX']},
#  {'name': 'Darcrus',
#   'rank': 967,
#   'slug': 'darcrus',
#   'symbol': 'DAR',
#   'tokens': ['Darcrus', 'DAR']},
#  {'name': 'FundYourselfNow',
#   'rank': 968,
#   'slug': 'fundyourselfnow',
#   'symbol': 'FYN',
#   'tokens': ['FundYourselfNow', 'FYN']},
#  {'name': 'Ethereum Movie Venture',
#   'rank': 969,
#   'slug': 'ethereum-movie-venture',
#   'symbol': 'EMV',
#   'tokens': ['Ethereum Movie Venture', 'EMV']},
#  {'name': 'FIMKrypto',
#   'rank': 970,
#   'slug': 'fimkrypto',
#   'symbol': 'FIMK',
#   'tokens': ['FIMKrypto', 'FIMK']},
#  {'name': 'Gimli',
#   'rank': 971,
#   'slug': 'gimli',
#   'symbol': 'GIM',
#   'tokens': ['Gimli', 'GIM']},
#  {'name': 'ICO OpenLedger',
#   'rank': 972,
#   'slug': 'ico-openledger',
#   'symbol': 'ICOO',
#   'tokens': ['ICO OpenLedger', 'ICOO']},
#  {'name': 'MetalCoin',
#   'rank': 973,
#   'slug': 'metalcoin',
#   'symbol': 'METAL',
#   'tokens': ['MetalCoin', 'METAL']},
#  {'name': 'ShadowCash',
#   'rank': 974,
#   'slug': 'shadowcash',
#   'symbol': 'SDC',
#   'tokens': ['ShadowCash', 'SDC']},
#  {'name': 'PiplCoin',
#   'rank': 975,
#   'slug': 'piplcoin',
#   'symbol': 'PIPL',
#   'tokens': ['PiplCoin', 'PIPL']},
#  {'name': 'Monster Byte',
#   'rank': 976,
#   'slug': 'monster-byte',
#   'symbol': 'MBI',
#   'tokens': ['Monster Byte', 'MBI']},
#  {'name': 'FlutterCoin',
#   'rank': 977,
#   'slug': 'fluttercoin',
#   'symbol': 'FLT',
#   'tokens': ['FlutterCoin', 'FLT']},
#  {'name': 'KekCoin',
#   'rank': 978,
#   'slug': 'kekcoin',
#   'symbol': 'KEK',
#   'tokens': ['KekCoin', 'KEK']},
#  {'name': 'StarCredits',
#   'rank': 979,
#   'slug': 'starcredits',
#   'symbol': 'STRC',
#   'tokens': ['StarCredits', 'STRC']},
#  {'name': 'Smart Investment Fund Token',
#   'rank': 980,
#   'slug': 'smart-investment-fund-token',
#   'symbol': 'SIFT',
#   'tokens': ['Smart Investment Fund Token', 'SIFT']},
#  {'name': 'Rustbits',
#   'rank': 981,
#   'slug': 'rustbits',
#   'symbol': 'RUSTBITS',
#   'tokens': ['Rustbits', 'RUSTBITS']},
#  {'name': 'Orbitcoin',
#   'rank': 982,
#   'slug': 'orbitcoin',
#   'symbol': 'ORB',
#   'tokens': ['Orbitcoin', 'ORB']},
#  {'name': 'Rasputin Online Coin',
#   'rank': 983,
#   'slug': 'rasputin-online-coin',
#   'symbol': 'ROC',
#   'tokens': ['Rasputin Online Coin', 'ROC']},
#  {'name': 'I0Coin',
#   'rank': 984,
#   'slug': 'i0coin',
#   'symbol': 'I0C',
#   'tokens': ['I0Coin', 'I0C']},
#  {'name': 'Emphy',
#   'rank': 985,
#   'slug': 'emphy',
#   'symbol': 'EPY',
#   'tokens': ['Emphy', 'EPY']},
#  {'name': 'Shorty',
#   'rank': 986,
#   'slug': 'shorty',
#   'symbol': 'SHORTY',
#   'tokens': ['Shorty', 'SHORTY']},
#  {'name': 'Ultimate Secure Cash',
#   'rank': 987,
#   'slug': 'ultimate-secure-cash',
#   'symbol': 'USC',
#   'tokens': ['Ultimate Secure Cash', 'USC']},
#  {'name': 'BlakeStar',
#   'rank': 988,
#   'slug': 'blakestar',
#   'symbol': 'BLAS',
#   'tokens': ['BlakeStar', 'BLAS']},
#  {'name': 'Link Platform',
#   'rank': 989,
#   'slug': 'link-platform',
#   'symbol': 'LNK',
#   'tokens': ['Link Platform', 'LNK']},
#  {'name': 'Giga Watt Token',
#   'rank': 990,
#   'slug': 'giga-watt-token',
#   'symbol': 'WTT',
#   'tokens': ['Giga Watt Token', 'WTT']},
#  {'name': 'Fantomcoin',
#   'rank': 991,
#   'slug': 'fantomcoin',
#   'symbol': 'FCN',
#   'tokens': ['Fantomcoin', 'FCN']},
#  {'name': 'CryptoInsight',
#   'rank': 992,
#   'slug': 'trackr',
#   'symbol': 'TKR',
#   'tokens': ['CryptoInsight', 'TKR']},
#  {'name': 'Woodcoin',
#   'rank': 993,
#   'slug': 'woodcoin',
#   'symbol': 'LOG',
#   'tokens': ['Woodcoin', 'LOG']},
#  {'name': 'Trollcoin',
#   'rank': 994,
#   'slug': 'trollcoin',
#   'symbol': 'TROLL',
#   'tokens': ['Trollcoin', 'TROLL']},
#  {'name': 'Nimfamoney',
#   'rank': 995,
#   'slug': 'nimfamoney',
#   'symbol': 'NIMFA',
#   'tokens': ['Nimfamoney', 'NIMFA']},
#  {'name': 'GAIA',
#   'rank': 996,
#   'slug': 'gaia',
#   'symbol': 'GAIA',
#   'tokens': ['GAIA', 'GAIA']},
#  {'name': 'Bitpark Coin',
#   'rank': 997,
#   'slug': 'bitpark-coin',
#   'symbol': 'BPC',
#   'tokens': ['Bitpark Coin', 'BPC']},
#  {'name': 'HoboNickels',
#   'rank': 998,
#   'slug': 'hobonickels',
#   'symbol': 'HBN',
#   'tokens': ['HoboNickels', 'HBN']},
#  {'name': 'Opal',
#   'rank': 999,
#   'slug': 'opal',
#   'symbol': 'OPAL',
#   'tokens': ['Opal', 'OPAL']},
#  {'name': 'Nyancoin',
#   'rank': 1000,
#   'slug': 'nyancoin',
#   'symbol': 'NYAN',
#   'tokens': ['Nyancoin', 'NYAN']},
#  ...]

# %% [markdown]
# ## Exercise (2)
# Now visit one of the links and see what data you can get.
#
# **Backdoors**
# - Look at the network monitor and locate the link to the file with the historical trading data (i.e. the graph displayed).
# - See how the link is constructed, and make a loop that collects and stores the first 5 companies.

# %% [markdown]
# ## Solution (2)
# - visit the following: https://coinmarketcap.com/currencies/singularitynet/
# - What data can you get?
# - Inspect the network monitor and find the data behind the generated graph.

# %%
! mkdir crypto_data

# %%
import json
import tqdm
for coin in tqdm.tqdm(coins[0:5]):
    slug = coin['slug']

    graph_link = 'https://graphs2.coinmarketcap.com/currencies/%s/'%slug
#        response = request(graph_link)
    graph_data = request(graph_link).json()
    filename = 'crypto_data/trading_data_%s'%slug
    f = open(filename,'w')
    json.dump(graph_data,f)
# Out:
# mkdir: crypto_data: File exists
# 100%|██████████| 5/5 [00:07<00:00,  1.45s/it]

# %%
import random
from os import listdir
path = 'crypto_data/'
files = [path+i for i in listdir(path)]
random_file = random.choice(files)
graph_data = json.load(open(random_file,'r'))
x,y = zip(*graph_data['volume_usd'])

# %%
#graph_data['volume_usd']

# %%
import datetime
plt.figure(figsize=(15,5))
plt.plot([datetime.datetime.fromtimestamp(i/1000) for i in x],y)
plt.title(random_file.split('_')[-1])
#sns.tsplot(pd.DataFrame({'t':[datetime.datetime.fromtimestamp(i/1000) for i in x],'y':y}),time='t',unit='y')

# %% [markdown]
# ## Exercise (3)
# ** HTML parsing **
#
# Now we need to visit the pages and collect data stored in the html.
#
# Use the links collected before and store the first 5 raw html responses
#
# * Design a parser that collects the Twitter handle of each company - from the Social Media Feed option (+whatever meta data you like) - and apply it to the raw html.
#     - Note not all companies has a twitter handle.

# %% [markdown]
# ## Solution (3)

# %%
# get raw_html
! mkdir crypto_data/coinmarket_html

# %%
from os import listdir
path = 'crypto_data/coinmarket_html/'
already_collected = listdir(path)
# add already seen

for coin in tqdm.tqdm(coins[0:5]):
    slug = coin['slug']
    if slug in already_collected:
        continue
    url = 'https://coinmarketcap.com/currencies/%s/'%slug
    response = request(url)#social')
    if response.ok:
        dumpfile = open('crypto_data/coinmarket_html/%s'%slug,'w')
        dumpfile.write(response.text)
        dumpfile.close()
# Out:
# 100%|██████████| 5/5 [00:08<00:00,  1.65s/it]

# %%
path = 'crypto_data/coinmarket_html/'
files = [path+filename for filename in listdir(path)]
for filename in files:
    html = open(filename,'r').read()
    soup = soup = BeautifulSoup(html,'lxml')
    # function to parse html here

# %%
soup # inspect the soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ4BV1dWDxABVFdQAQIEX1M="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t) ...
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Ripple (XRP) price, charts, market cap, and other metrics | CoinMarketCap</title>
# <meta content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A" name="google-site-verification"/>
# <meta content="website" property="og:type"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="http://files.coinmarketcap.com.s3-website-us-east-1.amazonaws.com/static/img/coins/200x200/ripple.png" property="og:image"/>
# <meta content="Ripple (XRP) price, charts, market cap, and other metrics | CoinMarketCap" property="og:title"/>
# <meta content="Get Ripple price, charts, and other cryptocurrency info" name="description"/>
# <meta content="Get Ripple price, charts, and other cryptocurrency info" property="og:description"/>
# <link href="https://files.coinmarketcap.com/static/img/coins/16x16/ripple.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://files.coinmarketcap.com/static/img/coins/32x32/ripple.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://coinmarketcap.com/currencies/ripple/" rel="canonical"/>
# <link href="https://coinmarketcap.com/de/currencies/ripple/" hreflang="de" rel="alternate"/>
# <link href="https://coinmarketcap.com/currencies/ripple/" hreflang="en" rel="alternate"/>
# <link href="https://coinmarketcap.com/es/currencies/ripple/" hreflang="es" rel="alternate"/>
# <link href="https://coinmarketcap.com/fil/currencies/ripple/" hreflang="fil" rel="alternate"/>
# <link href="https://coinmarketcap.com/fr/currencies/ripple/" hreflang="fr" rel="alternate"/>
# <link href="https://coinmarketcap.com/hi/currencies/ripple/" hreflang="hi" rel="alternate"/>
# <link href="https://coinmarketcap.com/it/currencies/ripple/" hreflang="it" rel="alternate"/>
# <link href="https://coinmarketcap.com/ko/currencies/ripple/" hreflang="ko" rel="alternate"/>
# <link href="https://coinmarketcap.com/ja/currencies/ripple/" hreflang="ja" rel="alternate"/>
# <link href="https://coinmarketcap.com/pt-br/currencies/ripple/" hreflang="pt-br" rel="alternate"/>
# <link href="https://coinmarketcap.com/ru/currencies/ripple/" hreflang="ru" rel="alternate"/>
# <link href="https://coinmarketcap.com/vi/currencies/ripple/" hreflang="vi" rel="alternate"/>
# <link href="https://coinmarketcap.com/zh/currencies/ripple/" hreflang="zh" rel="alternate"/>
# <link href="https://s2.coinmarketcap.com/static/cloud/compressed/base.5f282daf.min.css" rel="stylesheet"/>
# <script>
#         function getCookie(e){var n=" "+document.cookie,t=" "+e+"=",i=null,o=0,u=0;return n.length>0&&-1!=(o=n.indexOf(t))&&(o+=t.length,-1==(u=n.indexOf(";",o))&&(u=n.length),i=unescape(n.substring(o,u))),i}
#
#         var DEFAULT_CURRENCY = 'USD';
#         dataLayer = [{
#             'section': 'Details',
#             'subSection': 'Currencies',
#             'firstSessionDate': getCookie('gtm_session_first'),
#             'lastSessionDate': getCookie('gtm_session_last'),
#             'language': 'en',
#             'currency': getCookie('currency') || DEFAULT_CURRENCY,
#             'siteTheme': getCookie('theme') || 'day'
#         }];
#         </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MNVXW26');
#         </script>
# <script>
#             var NightMode = (function () {
#                 var key = 'theme', on = 'night', off = 'day';
#                 var _trackEvent = function (value) {
#                     dataLayer.push({
#                         'event': 'customEvent',
#                         'eventCategory': 'Night Mode',
#                         'eventAction': 'Night Mode Toggled',
#                         'eventLabel': value
#                     });
#                 };
#                 var _setCookie = function (value) {
#                     Cookies.set(key, value, {expires: 3650});
#                 };
#                 var _activateSwitch = function (value) {
#                     if (value) {
#                         $('[data-night-mode-on]').addClass('active');
#                         $('[data-night-mode-off]').removeClass('active');
#                     } else {
#                         $('[data-night-mode-on]').removeClass('active');
#                         $('[data-night-mode-off]').addClass('active');
#                     }
#                 };
#                 var initSwitch = function () {
#                     $('[data-night-mode-on]').click(function () {
#                         $('body').addClass('night-mode');
#                         _activateSwitch(true);
#                         _setCookie(on);
#                         _trackEvent('on');
#                     });
#                     $('[data-night-mode-off]').click(function () {
#                         $('body').removeClass('night-mode');
#                         _activateSwitch(false);
#                         _setCookie(off);
#                         _trackEvent('off');
#                     });
#
#                     _activateSwitch(Cookies.get(key) === on);
#                 };
#                 var init = function () {
#                     if (getCookie(key) === on) {
#                         var nightModeClass = 'night-mode';
#                         var currentClass = document.body.className;
#                         if (currentClass.length > 0) {
#                             if (currentClass.indexOf(nightModeClass) === -1) {
#                                 document.body.className = currentClass + ' ' + nightModeClass;
#                             }
#                         } else {
#                             document.body.className = nightModeClass;
#                         }
#                     }
#                 };
#                 return {initSwitch: initSwitch, init: init};
#             })();
#         </script>
# <script async="async" src="https://s2.coinmarketcap.com/static/cloud/compressed/prebid.cb5bd327.min.js"></script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             googletag.cmd.push(function() {
#                 googletag.pubads().disableInitialLoad();
#             });
#         </script>
# <script>
#           googletag.cmd.push(function() {
#
#
#                     googletag.defineSlot('/48901027/non_landing_leaderboard_top', [728, 90], 'div-gpt-ad-1488495260324-9').addService(googletag.pubads());
#                     googletag.defineSlot('/48901027/non_landing_side', [160, 600], 'div-gpt-ad-1488495260324-10').addService(googletag.pubads());
#                     googletag.defineSlot('/48901027/non_landing_leaderboard_bottom', [728, 90], 'div-gpt-ad-1488495260324-8').addService(googletag.pubads());
#
#
#
#
#                 googletag.pubads().setTargeting("coin_id","52");
#
#
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#           });
#         </script>
# <script>
#
#         //Load the UAM JavaScript Library
#         !function(a9,a,p,s,t,A,g){if(a[a9])return;function
#         q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#         apstag.init({
#             pubID: '1edde03c-121e-457d-9c35-ad4fca989bac',
#             adServer: 'googletag',
#             bidTimeout: 2000
#         });
#
#         var pbjs = pbjs || {};
#         pbjs.que = pbjs.que || [];
#
#         </script>
# <script>
#         function fetchHeaderBids() {
#             var bidTimeout = 2000;
#             var adUnits = [
#
#
#                     {
#                         code: 'div-gpt-ad-1488495260324-9',
#                         sizes: [[728, 90]],
#                         bids: [
#                         {
#                             "bidder": "appnexus",
#                             "params": {
#                                 "placementId": "11835084" // [D] 728x90 Detail ATF: 11835084
#                             }
#                         },
#                         {
#                             "bidder": "indexExchange",
#                             "params": {
#                                 "id": "4",
#                                 "siteID": "219067" // coinmarketcap.com_Desktop_728x90_ATF Detail
#                             }
#                         }]
#                     },{
#                         code: 'div-gpt-ad-1488495260324-10',
#                         sizes: [[160, 600]],
#                         bids: [
#                         {
#                             "bidder": "openx",
#                             "params": {
#                                 "unit": "539181152",
#                                 "delDomain": "coinmarketcap-d.openx.net" // Desktop - 160x600 Detail page
#                             }
#                         },
#                         {
#                             "bidder": "appnexus",
#                             "params": {
#                                 "placementId": "11835085" // [D] 160x600 Detail: 11835085
#                             }
#                         },
#                         {
#                             "bidder": "indexExchange",
#                             "params": {
#                                 "id": "5",
#                                 "siteID": "219068" // coinmarketcap.com_Desktop_160x600_Side Detail
#                             }
#                         },
#                         {
#                             "bidder": "sovrn",
#                             "params": {
#                                 "tagid": "496633" // CoinMarketCap_AiH_160x600_Side_DETAILPAGE_Desktop
#                             }
#                         }]
#                     },{
#                         code: 'div-gpt-ad-1488495260324-8',
#                         sizes: [[728, 90]],
#                         bids: [
#                         {
#                             "bidder": "openx",
#                             "params": {
#                                 "unit": "539181150",
#                                 "delDomain": "coinmarketcap-d.openx.net" // Desktop - 728x90 BTF Detail page
#                             }
#                         },
#                         {
#                             "bidder": "appnexus",
#                             "params": {
#                                 "placementId": "11835086" // [D] 728x90 Detail BTF: 11835086
#                             }
#                         },
#                         {
#                             "bidder": "indexExchange",
#                             "params": {
#                                 "id": "6",
#                                 "siteID": "219069" // coinmarketcap.com_Desktop_728x90_BTF Detail
#                             }
#                         },
#                         {
#                             "bidder": "sovrn",
#                             "params": {
#                                 "tagid": "496631" // CoinMarketCap_AiH_728x90_BTF_DETAILPAGE_Desktop
#                             }
#                         }]
#                     }
#
#
#             ];
#
#             var apstagSlots = [
#
#
#                     {
#                         slotID: 'div-gpt-ad-1488495260324-9',
#                         slotName: '/48901027/non_landing_leaderboard_top',
#                         sizes: [[728, 90]]
#                     },
#                     {
#                         slotID: 'div-gpt-ad-1488495260324-10',
#                         slotName: '/48901027/non_landing_side',
#                         sizes: [[160, 600]]
#                     },
#                     {
#                         slotID: 'div-gpt-ad-1488495260324-8',
#                         slotName: '/48901027/non_landing_leaderboard_bottom',
#                         sizes: [[728, 90]]
#                     }
#
#
#             ];
#
#             var bidders = ['a9', 'prebid'];
#
#             var requestManager = {
#                 adserverRequestSent: false,
#             };
#
#                 bidders.forEach(function(bidder) {
#                 requestManager[bidder] = false;
#             })
#
#             function allBiddersBack() {
#                 var allBiddersBack = bidders
#                 .map(function(bidder) {
#                     return requestManager[bidder];
#                 })
#                 .filter(Boolean)
#                 .length === bidders.length;
#                 return allBiddersBack;
#             }
#
#             function headerBidderBack(bidder) {
#                 if (requestManager.adserverRequestSent === true) {
#                     return;
#                 }
#                 if (bidder === 'a9') {
#                     requestManager.a9 = true;
#                 } else if (bidder === 'prebid') {
#                     requestManager.prebid = true;
#                 }
#                 if (allBiddersBack()) {
#                     sendAdserverRequest();
#                 }
#             }
#
#             function sendAdserverRequest() {
#                 if (requestManager.adserverRequestSent === true) {
#                     return;
#                 }
#
#                 requestManager.adserverRequestSent = true;
#                 pbjs.adserverRequestSent = true;
#                 requestManager.sendAdserverRequest = true;
#                 googletag.cmd.push(function() {
#                     apstag.setDisplayBids();
#                     if (pbjs.version) {
#                         pbjs.setTargetingForGPTAsync();
#                     }
#                     googletag.pubads().refresh();
#                 });
#             }
#
#             function requestBids(apstagSlots, adUnits, bidTimeout) {
#                 apstag.fetchBids({
#                     slots: apstagSlots,
#                     timeout: bidTimeout
#                     }, function(bids) {
#                         headerBidderBack('a9');
#                     });
#
#                 // request bids from prebid
#                 pbjs.que.push(function() {
#                     pbjs.setPriceGranularity("high");
#                     pbjs.addAdUnits(adUnits);
#                     pbjs.enableSendAllBids();
#                     pbjs.bidderSettings = {
#                       appnexus: {
#                         bidCpmAdjustment : function(bidCpm){
#                           return bidCpm * 0.66;
#                         }
#                       },
#                       openx: {
#                         bidCpmAdjustment : function(bidCpm){
#                           return bidCpm * 0.80;
#                         }
#                       }
#                     };
#
#                     pbjs.requestBids({
#                         bidsBackHandler: function (bids) {
#                             headerBidderBack('prebid');
#                         }
#                     });
#                 });
#             }
#
#             requestBids(apstagSlots, adUnits, bidTimeout)
#             window.setTimeout(function() {
#                 sendAdserverRequest();
#             }, bidTimeout);
#         };
#
#         fetchHeaderBids();
#
#         </script>
# <style>
#         .header-banner-close {
#             z-index:1000;
#             color:#000;
#         }
#         #header-banner-wrapper {
#             text-align:center;
#             background-color:#FFF;
#             max-height:90px;
#         }
#
#         #header-banner-wrapper a:hover{text-decoration:none;}
#     </style>
# </head>
# <body>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MNVXW26" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!--[if lt IE 7]>
#             <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to improve your experience.</p>
#         <![endif]-->
# <script>
#             NightMode.init();
#         </script>
# <link href="https://files.coinmarketcap.com/static/sponsored/xinfin/assets/css/style.css" media="all" rel="stylesheet" type="text/css"/>
# <div id="header-banner-wrapper" style="display:none;overflow-x: hidden;">
# <a href="https://xinfin.io" rel="nofollow" target="_blank">
# <div class="particles" id="particles-js" style="background: none"></div>
# <div class="xdce-banner">
# <div class="xdce-col-left">
# <img alt="XinFin" src="https://files.coinmarketcap.com/static/sponsored/xinfin/assets/images/xinfin-logo.svg"/>
# </div>
# <div class="xdce-col-center-1">
# <div class="xdce-slide" id="xdce-slide-1">
# <div class="xdce-text"><strong>XinFin</strong> Hybrid Blockchain</div>
# <div class="xdce-text orange">Ready product for $50 trillion Global Trade and Finance</div>
# </div>
# </div>
# <div class="xdce-col-right">
# <p>First Round Ends In</p>
# <div class="xdce-countdown">
# <div>
# <div id="xdce-countdown-days">01</div>
# <small>days</small>
# </div>
# <div>
# <div id="xdce-countdown-hours">12</div>
# <small>hours</small>
# </div>
# <div>
# <div id="xdce-countdown-minutes">45</div>
# <small>mins</small>
# </div>
# <div>
# <div id="xdce-countdown-seconds">15</div>
# <small>secs</small>
# </div>
# </div>
# </div>
# <div class="xdce-col-center-2">
# <div class="xdce-slide" id="xdce-slide-3">
# <div class="xdce-text">Get <span>30%</span> Bonus</div>
# <div class="xdce-button">Contribute Now</div>
# </div>
# </div>
# </div>
# </a>
# <div class="header-banner-close">X</div>
# </div>
# <script>
#             if (getCookie("header-banner-noshow") != "1") {
#                 document.getElementById('header-banner-wrapper').style.display = 'block';
#             }
#         </script>
# <nav class="navbar mobile navbar-default visible-xs">
# <div class="container-fluid">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#mobile-navbar-dropdown" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <h2><a class="navbar-brand" href="/">CoinMarketCap</a></h2>
# </div>
# <div class="collapse navbar-collapse" id="mobile-navbar-dropdown">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Market Cap <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li><a href="/">All</a></li>
# <li><a href="/coins/">Coins</a></li>
# <li><a href="/tokens/">Tokens</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Trade Volume <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li><a href="/currencies/volume/24-hour/">24 Hour Volume Rankings (Currency)</a></li>
# <li><a href="/exchanges/volume/24-hour/">24 Hour Volume Rankings (Exchange)</a></li>
# <li><a href="/currencies/volume/monthly/">Monthly Volume Rankings (Currency)</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Trending <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li><a href="/gainers-losers/">Gainers and Losers</a></li>
# <li><a href="/new/">Recently Added</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Tools <span class="caret"></span></a>
# <ul class="dropdown-menu">
# <li><a href="/charts/">Global Charts</a></li>
# <li><a href="/historical/">Historical Snapshots</a></li>
# <li><a href="/calculator/">Currency Converter Calculator</a></li>
# <li><a href="/widget/">Website Widgets</a></li>
# </ul>
# </li>
# </ul>
# <form action="/currencies/search/" class="navbar-form quick-search-container" role="search">
# <div class="form-group">
# <input class="form-control quick-search-box js-quick-search" name="q" placeholder="Search Currencies" type="text"/>
# <button class="btn btn-primary" type="submit"><i class="glyphicon glyphicon-search"></i></button>
# </div>
# <div class="clearfix"></div>
# </form>
# <div class="navbar-text">
# <div class="btn-group">
# <button class="btn btn-xs dropdown-toggle language-dropdown" data-toggle="dropdown" type="button">
# <span data-language-dropdown="">English</span> <span class="caret"></span>
# </button>
# <ul class="dropdown-menu language-dropdown-menu text-center" role="menu">
# <li class="pointer"><a data-language-toggle="de" href="/de/currencies/ripple/">Deutsch</a></li>
# <li class="pointer"><a data-language-toggle="en" href="/currencies/ripple/">English</a></li>
# <li class="pointer"><a data-language-toggle="es" href="/es/currencies/ripple/">Español</a></li>
# <li class="pointer"><a data-language-toggle="fil" href="/fil/currencies/ripple/">Filipino</a></li>
# <li class="pointer"><a data-language-toggle="fr" href="/fr/currencies/ripple/">Français</a></li>
# <li class="pointer"><a data-language-toggle="hi" href="/hi/currencies/ripple/">हिन्दी</a></li>
# <li class="pointer"><a data-language-toggle="it" href="/it/currencies/ripple/">Italiano</a></li>
# <li class="pointer"><a data-language-toggle="ko" href="/ko/currencies/ripple/">한국어</a></li>
# <li class="pointer"><a data-language-toggle="ja" href="/ja/currencies/ripple/">日本語</a></li>
# <li class="pointer"><a data-language-toggle="pt-br" href="/pt-br/currencies/ripple/">Português Brasil</a></li>
# <li class="pointer"><a data-language-toggle="ru" href="/ru/currencies/ripple/">Русский</a></li>
# <li class="pointer"><a data-language-toggle="vi" href="/vi/currencies/ripple/">Tiếng Việt</a></li>
# <li class="pointer"><a data-language-toggle="zh" href="/zh/currencies/ripple/">简体中文</a></li>
# </ul>
# </div>
# <div class="btn-group global-currency-dropdown-container" data-global-currency-switch="">
# <button class="btn btn-xs dropdown-toggle global-currency-dropdown" data-toggle="dropdown" type="button">
# <span data-currency-display="">USD</span> <span class="caret"></span>
# </button>
# <ul class="dropdown-menu global-currency-dropdown-menu text-center" role="menu">
# <li class="pointer"><a data-currency-toggle="">USD</a></li>
# <li class="pointer"><a data-currency-toggle="">DKK</a></li>
# <li class="pointer"><a data-currency-toggle="">JPY</a></li>
# <li class="pointer"><a data-currency-toggle="">PLN</a></li>
# <li class="pointer"><a data-currency-toggle="">AUD</a></li>
# <li class="pointer"><a data-currency-toggle="">EUR</a></li>
# <li class="pointer"><a data-currency-toggle="">KRW</a></li>
# <li class="pointer"><a data-currency-toggle="">RUB</a></li>
# <li class="pointer"><a data-currency-toggle="">BRL</a></li>
# <li class="pointer"><a data-currency-toggle="">GBP</a></li>
# <li class="pointer"><a data-currency-toggle="">MXN</a></li>
# <li class="pointer"><a data-currency-toggle="">SEK</a></li>
# <li class="pointer"><a data-currency-toggle="">CAD</a></li>
# <li class="pointer"><a data-currency-toggle="">HKD</a></li>
# <li class="pointer"><a data-currency-toggle="">MYR</a></li>
# <li class="pointer"><a data-currency-toggle="">SGD</a></li>
# <li class="pointer"><a data-currency-toggle="">CHF</a></li>
# <li class="pointer"><a data-currency-toggle="">HUF</a></li>
# <li class="pointer"><a data-currency-toggle="">NOK</a></li>
# <li class="pointer"><a data-currency-toggle="">THB</a></li>
# <li class="pointer"><a data-currency-toggle="">CLP</a></li>
# <li class="pointer"><a data-currency-toggle="">IDR</a></li>
# <li class="pointer"><a data-currency-toggle="">NZD</a></li>
# <li class="pointer"><a data-currency-toggle="">TRY</a></li>
# <li class="pointer"><a data-currency-toggle="">CNY</a></li>
# <li class="pointer"><a data-currency-toggle="">ILS</a></li>
# <li class="pointer"><a data-currency-toggle="">PHP</a></li>
# <li class="pointer"><a data-currency-toggle="">TWD</a></li>
# <li class="pointer"><a data-currency-toggle="">CZK</a></li>
# <li class="pointer"><a data-currency-toggle="">INR</a></li>
# <li class="pointer"><a data-currency-toggle="">PKR</a></li>
# <li class="pointer"><a data-currency-toggle="">ZAR</a></li>
# </ul>
# </div>
# </div>
# <p class="navbar-text">
# <a href="https://www.facebook.com/CoinMarketCap" target="_blank"><img alt="twitter" class="icon-social" src="https://s2.coinmarketcap.com/static/cloud/img/facebook_logo.png"/></a>
# &amp;hairsp;
# <a href="https://twitter.com/CoinMarketCap" target="_blank"><img alt="twitter" class="icon-social" src="https://s2.coinmarketcap.com/static/cloud/img/twitter_logo.png"/></a>
# </p>
# </div>
# </div>
# </nav>
# <div class="global-stats mobile visible-xs" data-global-stats-container="">
# <ul class="list-group">
# <li class="list-group-item">
# Market Cap: <strong><a href="/charts/"><span data-global-currency-market-cap="" data-global-stats-market-cap=""></span></a></strong>
# <button aria-controls="global-stats-mobile" aria-expanded="false" class="pull-right dropdown-toggle" data-target="#global-stats-mobile" data-toggle="collapse"><span class="caret"></span></button>
# </li>
# </ul>
# <div class="collapse" id="global-stats-mobile">
# <ul class="list-group">
# <li class="list-group-item">24h Vol: <strong><a href="/charts/"><span data-global-currency-volume="" data-global-stats-volume=""></span></a></strong></li>
# <li class="list-group-item">BTC Dominance: <strong><a href="/charts/#dominance-percentage"><span data-global-stats-btc-dominance=""></span>%</a></strong></li>
# <li class="list-group-item">Cryptocurrencies: <strong><a href="/all/views/all/"><span data-global-stats-cryptocurrencies=""></span></a></strong></li>
# <li class="list-group-item">Markets: <strong><a href="/currencies/volume/24-hour/"><span data-global-stats-markets=""></span></a></strong></li>
# </ul>
# </div>
# </div>
# <div class="outer-container global-stats desktop hidden-xs">
# <div class="container global-stats desktop">
# <div class="row">
# <div class="col-sm-3">
# <ul class="list-inline stat-counters hidden" data-global-stats-container="">
# <li>Cryptocurrencies: <strong><a href="/all/views/all/"><span data-global-stats-cryptocurrencies=""></span></a></strong></li>
# <li>/ Markets: <strong><a href="/currencies/volume/24-hour/"><span data-global-stats-markets=""></span></a></strong></li>
# </ul>
# </div>
# <div class="col-sm-6 text-center">
# <ul class="list-inline stat-counters hidden" data-global-stats-container="">
# <li>Market Cap: <strong><a href="/charts/"><span data-global-currency-market-cap="" data-global-stats-market-cap=""></span></a></strong></li>
# <li> / 24h Vol: <strong><a href="/charts/"><span data-global-currency-volume="" data-global-stats-volume=""></span></a></strong> / BTC Dominance: <strong><a href="/charts/#dominance-percentage"><span data-global-stats-btc-dominance=""></span>%</a></strong></li>
# </ul>
# </div>
# <div class="col-sm-3 text-right">
# <div class="btn-group">
# <button class="btn btn-xs dropdown-toggle language-dropdown" data-toggle="dropdown" type="button">
# <span data-language-dropdown="">English</span> <span class="caret"></span>
# </button>
# <ul class="dropdown-menu language-dropdown-menu text-center" role="menu">
# <li class="pointer"><a data-language-toggle="de" href="/de/currencies/ripple/">Deutsch</a></li>
# <li class="pointer"><a data-language-toggle="en" href="/currencies/ripple/">English</a></li>
# <li class="pointer"><a data-language-toggle="es" href="/es/currencies/ripple/">Español</a></li>
# <li class="pointer"><a data-language-toggle="fil" href="/fil/currencies/ripple/">Filipino</a></li>
# <li class="pointer"><a data-language-toggle="fr" href="/fr/currencies/ripple/">Français</a></li>
# <li class="pointer"><a data-language-toggle="hi" href="/hi/currencies/ripple/">हिन्दी</a></li>
# <li class="pointer"><a data-language-toggle="it" href="/it/currencies/ripple/">Italiano</a></li>
# <li class="pointer"><a data-language-toggle="ko" href="/ko/currencies/ripple/">한국어</a></li>
# <li class="pointer"><a data-language-toggle="ja" href="/ja/currencies/ripple/">日本語</a></li>
# <li class="pointer"><a data-language-toggle="pt-br" href="/pt-br/currencies/ripple/">Português Brasil</a></li>
# <li class="pointer"><a data-language-toggle="ru" href="/ru/currencies/ripple/">Русский</a></li>
# <li class="pointer"><a data-language-toggle="vi" href="/vi/currencies/ripple/">Tiếng Việt</a></li>
# <li class="pointer"><a data-language-toggle="zh" href="/zh/currencies/ripple/">简体中文</a></li>
# </ul>
# </div>
# <div class="btn-group global-currency-dropdown-container" data-global-currency-switch="">
# <button class="btn btn-xs dropdown-toggle global-currency-dropdown" data-toggle="dropdown" type="button">
# <span data-currency-display="">USD</span> <span class="caret"></span>
# </button>
# <ul class="dropdown-menu global-currency-dropdown-menu text-center" role="menu">
# <li class="pointer"><a data-currency-toggle="">USD</a></li>
# <li class="pointer"><a data-currency-toggle="">DKK</a></li>
# <li class="pointer"><a data-currency-toggle="">JPY</a></li>
# <li class="pointer"><a data-currency-toggle="">PLN</a></li>
# <li class="pointer"><a data-currency-toggle="">AUD</a></li>
# <li class="pointer"><a data-currency-toggle="">EUR</a></li>
# <li class="pointer"><a data-currency-toggle="">KRW</a></li>
# <li class="pointer"><a data-currency-toggle="">RUB</a></li>
# <li class="pointer"><a data-currency-toggle="">BRL</a></li>
# <li class="pointer"><a data-currency-toggle="">GBP</a></li>
# <li class="pointer"><a data-currency-toggle="">MXN</a></li>
# <li class="pointer"><a data-currency-toggle="">SEK</a></li>
# <li class="pointer"><a data-currency-toggle="">CAD</a></li>
# <li class="pointer"><a data-currency-toggle="">HKD</a></li>
# <li class="pointer"><a data-currency-toggle="">MYR</a></li>
# <li class="pointer"><a data-currency-toggle="">SGD</a></li>
# <li class="pointer"><a data-currency-toggle="">CHF</a></li>
# <li class="pointer"><a data-currency-toggle="">HUF</a></li>
# <li class="pointer"><a data-currency-toggle="">NOK</a></li>
# <li class="pointer"><a data-currency-toggle="">THB</a></li>
# <li class="pointer"><a data-currency-toggle="">CLP</a></li>
# <li class="pointer"><a data-currency-toggle="">IDR</a></li>
# <li class="pointer"><a data-currency-toggle="">NZD</a></li>
# <li class="pointer"><a data-currency-toggle="">TRY</a></li>
# <li class="pointer"><a data-currency-toggle="">CNY</a></li>
# <li class="pointer"><a data-currency-toggle="">ILS</a></li>
# <li class="pointer"><a data-currency-toggle="">PHP</a></li>
# <li class="pointer"><a data-currency-toggle="">TWD</a></li>
# <li class="pointer"><a data-currency-toggle="">CZK</a></li>
# <li class="pointer"><a data-currency-toggle="">INR</a></li>
# <li class="pointer"><a data-currency-toggle="">PKR</a></li>
# <li class="pointer"><a data-currency-toggle="">ZAR</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-lg-10">
# <div class="hidden-xs" id="title"><a href="/">Cryptocurrency Market Capitalizations</a></div>
# <hr class="divider-under-title"/>
# <div class="text-center" id="leaderboard">
# <div class="centered leaderboard" id="div-gpt-ad-1488495260324-9">
# <script>
#                                     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1488495260324-9'); });
#                                     </script>
# </div>
# </div>
# <nav class="navbar desktop navbar-default hidden-xs">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" id="navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Market Cap <span class="caret"></span></a>
# <ul class="dropdown-menu" role="menu">
# <li><a href="/">All</a></li>
# <li><a href="/coins/">Coins</a></li>
# <li><a href="/tokens/">Tokens</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Trade Volume <span class="caret"></span></a>
# <ul class="dropdown-menu" role="menu">
# <li><a href="/currencies/volume/24-hour/">24 Hour Volume Rankings (Currency)</a></li>
# <li><a href="/exchanges/volume/24-hour/">24 Hour Volume Rankings (Exchange)</a></li>
# <li><a href="/currencies/volume/monthly/">Monthly Volume Rankings (Currency)</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Trending <span class="caret"></span></a>
# <ul class="dropdown-menu" role="menu">
# <li><a href="/gainers-losers/">Gainers and Losers</a></li>
# <li><a href="/new/">Recently Added</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Tools <span class="caret"></span></a>
# <ul class="dropdown-menu" role="menu">
# <li><a href="/charts/">Global Charts</a></li>
# <li><a href="/historical/">Historical Snapshots</a></li>
# <li><a href="/calculator/">Currency Converter Calculator</a></li>
# <li><a href="/widget/">Website Widgets</a></li>
# </ul>
# </li>
# </ul>
# <form action="/currencies/search/" class="navbar-form navbar-right quick-search-container" role="search">
# <div class="form-group">
# <input class="form-control quick-search-box js-quick-search" name="q" placeholder="Search Currencies" type="text"/>
# </div>
# <button class="btn btn-primary" type="submit"><i class="glyphicon glyphicon-search"></i></button>
# </form>
# <div class="bottom-margin-1x hidden-sm hidden-md hidden-lg"></div>
# </div>
# </nav>
# <div class="row bottom-margin-1x">
# <div class="col-xs-6 col-sm-4 col-md-4">
# <h1 class="text-large">
# <img alt="Ripple" class="currency-logo-32x32" src="https://files.coinmarketcap.com/static/img/coins/32x32/ripple.png"/>
# <small class="bold hidden-sm hidden-md hidden-lg">(XRP)</small>
# <span class="clearfix visible-xs"></span>
# Ripple
# <small class="bold hidden-xs">(XRP)</small>
# </h1>
# </div>
# <div class="col-xs-6 col-sm-8 col-md-4 text-left">
# <span data-currency-price="" data-usd="1.09173" id="quote_price">
# <span class="text-large2" data-currency-value="">1.09</span>
# <span class="details-text-medium" data-currency-code="">USD</span>
# </span>
# <span class="text-large2 positive_change ">
# (<span data-format-percentage="" data-format-value="5.89445">5.89</span>%)
# </span>
# <br/>
# <span class="text-gray details-text-medium">
# <span data-format-price-crypto="" data-format-value="0.000118145">
# 0.00011815
# </span>
# BTC
# </span>
# <span class="details-text-medium negative_change">
# (<span data-format-percentage="" data-format-value="-0.840848">-0.84</span>%)
# </span>
# <div class="row">
# <div class="col-xs-12 col-sm-12 hidden-md hidden-lg text-left">
# <a href="http://iqoptioncom.com/5208bfc2-cef1-4b7d-b45b-fcb28b800a3d" rel="nofollow" target="_blank">
# <div class="btn btn-primary btn-xs"><span class="glyphicon glyphicon-flash"></span> Buy / Sell Instantly</div>
# </a>
# </div>
# </div>
# </div>
# <div class="hidden-xs hidden-sm col-md-4 text-left">
# <a href="http://iqoptioncom.com/5208bfc2-cef1-4b7d-b45b-fcb28b800a3d" rel="nofollow" target="_blank">
# <div class="btn btn-primary"><span class="glyphicon glyphicon-flash"></span>
# Buy instantly with credit card
# </div>
# </a>
# </div>
# </div>
# <div class="row bottom-margin-2x">
# <div class="col-sm-8 col-sm-push-4">
# <div class="coin-summary-item col-xs-6 col-md-3">
# <div class="coin-summary-item-header">
# <h3 class="details-text-medium">Market Cap</h3>
# </div>
# <div class="coin-summary-item-detail details-text-medium">
# <span data-currency-market-cap="" data-usd="42587531206.8">
# <span data-currency-value="">42,587,531,207</span>
# <span data-currency-code="">USD</span>
# </span><br/>
# <span class="text-gray">
# <span data-format-market-cap="" data-format-value="4608743.80518">
# 4,608,744
# </span>
# BTC
# <br/>
# </span>
# </div>
# </div>
# <div class="coin-summary-item col-xs-6 col-md-3">
# <div class="coin-summary-item-header">
# <h3 class="details-text-medium">Volume (24h)</h3>
# </div>
# <div class="coin-summary-item-detail details-text-medium">
# <span data-currency-volume="" data-usd="1030020000.0">
# <span data-currency-value="">1,030,020,000</span>
# <span data-currency-code="">USD</span>
# </span><br/>
# <span class="text-gray">
# <span data-format-value="111467.0" data-format-volume-crypto="">
# 111,467
# </span>
# BTC
# </span>
# </div>
# </div>
# <div class="vertical-spacer col-xs-12 hidden-md hidden-lg"></div>
# <div class="coin-summary-item col-xs-6 col-md-3">
# <div class="coin-summary-item-header">
# <h3 class="details-text-medium">Circulating Supply</h3>
# </div>
# <div class="coin-summary-item-detail details-text-medium">
# <span data-format-supply="" data-format-value="39009215838.0">
# 39,009,215,838
# </span>
# XRP
# </div>
# </div>
# <div class="coin-summary-item col-xs-6 col-md-3">
# <div class="coin-summary-item-header">
# <h3 class="details-text-medium">Total Supply</h3>
# </div>
# <div class="coin-summary-item-detail details-text-medium">
# <span data-format-supply="" data-format-value="99992725510.0">
# 99,992,725,510
# </span>
# XRP
# </div>
# </div>
# <div class="vertical-spacer col-xs-12 hidden-md"></div>
# <div class="clearfix visible-xs"></div>
# <div class="coin-summary-item col-xs-6 col-md-3 col-xs-offset-6 col-md-offset-9 ">
# <div class="coin-summary-item-header">
# <h3 class="details-text-medium">Max Supply</h3>
# </div>
# <div class="coin-summary-item-detail details-text-medium">
# <span data-format-supply="" data-format-value="100000000000">
# 100,000,000,000
# </span>
# XRP
# </div>
# </div>
# <div class="clearfix visible-xs"></div>
# </div>
# <div class="col-sm-4 col-sm-pull-8">
# <ul class="list-unstyled">
# <li><span class="glyphicon glyphicon-link text-gray" title="Website"></span> <a href="https://ripple.com/" target="_blank">Website</a></li>
# <li><span class="glyphicon glyphicon-search text-gray" title="Explorer"></span> <a href="https://xrpcharts.ripple.com/#/graph/" target="_blank">Explorer</a></li>
# <li><span class="glyphicon glyphicon-search text-gray" title="Explorer"></span> <a href="https://bithomp.com/explorer/" target="_blank">Explorer 2</a></li>
# <li><span class="glyphicon glyphicon-list text-gray" title="Message Board"></span> <a href="http://www.xrpchat.com/" target="_blank">Message Board</a></li>
# <li><span class="glyphicon glyphicon-globe text-gray" title="Chat"></span> <a href="https://t.me/Ripple" target="_blank">Chat</a></li>
# <li><span class="glyphicon glyphicon-globe text-gray" title="Chat"></span> <a href="https://discord.gg/N4x7kPb" target="_blank">Chat 2</a></li>
# <li><span class="glyphicon glyphicon-hdd text-gray" title="Source Code"></span> <a href="https://github.com/ripple" target="_blank">Source Code</a></li>
# <li><span class="glyphicon glyphicon glyphicon-star text-gray" title="Rank"></span>
# <small><span class="label label-success"> Rank 3</span></small>
# </li>
# <li><span class="glyphicon glyphicon glyphicon-tag text-gray" title="Tags"></span>
# <small><span class="label label-warning">Coin</span></small>
# </li>
# </ul>
# </div>
# </div>
# <div class="row bottom-margin-1x">
# <div class="col-xs-12">
# <ul class="nav nav-tabs text-left" role="tablist">
# <li><a data-toggle="tab" href="#charts" role="tab"> <span class="glyphicon glyphicon-stats text-gray"></span> Charts</a></li>
# <li><a data-toggle="tab" href="#markets" role="tab"><span class="glyphicon glyphicon-transfer text-gray"></span> Markets</a></li>
# <li><a data-toggle="tab" href="#social" role="tab"><span class="glyphicon glyphicon-globe text-gray"></span> Social</a></li>
# <li><a data-toggle="tab" href="#tools" role="tab"><span class="glyphicon glyphicon-wrench text-gray"></span> Tools</a></li>
# <li><a href="/currencies/ripple/historical-data/"><span class="glyphicon glyphicon-calendar text-gray"></span> Historical Data</a></li>
# </ul>
# </div>
# <div class="col-xs-12 tab-content">
# <div class="tab-pane active" id="charts">
# <div class="tab-header">
# <div class="text-center" id="highcharts-loading">Loading data from server...<div><span class="loading"></span></div></div>
# <div class="hidden text-center" id="highcharts-nodata">No chart data found</div>
# <div class="clear"></div>
# </div>
# <div id="highcharts-graph"></div>
# <div class="text-center">
# <button class="btn btn-default active" id="js-linear-mode">Linear Scale</button>
# <button class="btn btn-default" id="js-logarithmic-mode">Log Scale</button>
# </div>
# <br/>
# </div>
# <div class="tab-pane" id="markets">
# <div class="tab-header">
# <h2 class="pull-left">Ripple Markets</h2><br/>
# <div class="pull-right">
# <div class="clear"></div>
# <div class="btn-group" id="currency-switch">
# <button class="btn btn-primary dropdown-toggle" data-toggle="dropdown" id="currency-switch-button" type="button">
# USD <span class="caret"></span>
# </button>
# <ul class="dropdown-menu text-center" role="menu">
# <li class="pointer" data-fiat-item=""><a class="price-toggle" data-currency="usd" data-fiat="">USD</a></li>
# <li class="divider" data-fiat-item=""></li>
# <li class="pointer"><a class="price-toggle" data-currency="usd">USD</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="btc" data-currencyid="bitcoin">BTC</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="eth" data-currencyid="ethereum">ETH</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="xrp" data-currencyid="ripple">XRP</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="bch" data-currencyid="bitcoin-cash">BCH</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="ltc" data-currencyid="litecoin">LTC</a></li>
# <li class="divider"></li>
# <li class="pointer"><a class="price-toggle" data-currency="native">Native</a></li>
# </ul>
# </div>
# </div>
# <div class="table-responsive">
# <table class="table no-border table-condensed" id="markets-table">
# <thead>
# <tr>
# <th class="text-right sortable">#</th>
# <th class="sortable" id="th-source">Source</th>
# <th class="sortable" id="th-pair">Pair</th>
# <th class="text-right sortable">Volume (24h)</th>
# <th class="text-right sortable">Price</th>
# <th class="text-right sortable">Volume (%)</th>
# <th class="text-right sortable">Updated</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-right">1</td>
# <td><a href="/exchanges/bithumb/">Bithumb</a></td><td><a href="https://www.bithumb.com/" target="_blank">XRP/KRW</a></td>
# <td class="text-right">
# <span class="volume" data-btc="34607.8" data-native="288619000.0" data-usd="319798000.0">
# $319,798,000
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="0.000119908" data-native="1194.0" data-usd="1.10803">
# $1.11
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="31.0477466457">31.05</span>%
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr>
# <td class="text-right">2</td>
# <td><a href="/exchanges/upbit/">Upbit</a></td><td><a href="https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP" target="_blank">XRP/KRW</a></td>
# <td class="text-right">
# <span class="volume" data-btc="14244.1" data-native="118692000.0" data-usd="131624000.0">
# $131,624,000
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="0.000120009" data-native="1195.0" data-usd="1.10896">
# $1.11
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="12.7787809945">12.78</span>%
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr>
# <td class="text-right">3</td>
# <td><a href="/exchanges/bitfinex/">Bitfinex</a></td><td><a href="https://www.bitfinex.com/t/XRP:USD" target="_blank">XRP/USD</a></td>
# <td class="text-right">
# ...
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr>
# <td class="text-right">109</td>
# <td><a href="/exchanges/quoine/">Quoine</a></td><td><a href="https://quoinex.com/" target="_blank">XRP/IDR</a></td>
# <td class="text-right">
# <span class="volume" data-btc="0.0" data-native="0.0" data-usd="0.0">
# $0
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="2.30236e-07" data-native="29.0" data-usd="0.00212752">
# $0.002128
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="0.0">0.00</span>%
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr>
# <td class="text-right">110</td>
# <td><a href="/exchanges/quoine/">Quoine</a></td><td><a href="https://quoinex.com/" target="_blank">XRP/SGD</a></td>
# <td class="text-right">
# <span class="volume" data-btc="0.0" data-native="0.0" data-usd="0.0">
# $0
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="9.9367e-05" data-native="1.21" data-usd="0.918212">
# $0.918212
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="0.0">0.00</span>%
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr class="stale-box">
# <td class="text-right">111</td>
# <td><a href="/exchanges/xbtce/">xBTCe</a></td><td><a href="https://www.xbtce.com/xrpbtc" target="_blank">XRP/BTC</a></td>
# <td class="text-right">
# **
# <span class="volume" data-btc="0.0160699" data-native="146.09" data-usd="136.897">
# $137
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="0.00011" data-native="0.00011" data-usd="0.937074">
# $0.937074
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="0">0.00</span>%
# </td>
# <td class="text-right stale-box">174 hours ago</td>
# </tr>
# <tr class="stale-box">
# <td class="text-right">112</td>
# <td><a href="/exchanges/xbtce/">xBTCe</a></td><td><a href="https://www.xbtce.com/xrpusd" target="_blank">XRP/USD</a></td>
# <td class="text-right">
# **
# <span class="volume" data-btc="0.00246217" data-native="24.0" data-usd="22.752">
# $23
# </span>
# </td>
# <td class="text-right">
# <span class="price" data-btc="0.000102591" data-native="0.948" data-usd="0.948">
# $0.948000
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="0">0.00</span>%
# </td>
# <td class="text-right ">Recently</td>
# </tr>
# <tr class="stale-box">
# <td class="text-right">113</td>
# <td><a href="/exchanges/bitinka/">Bitinka</a></td><td><a href="https://www.bitinka.com.ar/" target="_blank">BTC/XRP</a></td>
# <td class="text-right">
# ***
# <span class="volume" data-btc="304.017" data-native="2095470.0" data-usd="2809310.0">
# $2,809,310
# </span>
# </td>
# <td class="text-right">
# ***
# <span class="price" data-btc="0.799929" data-native="1.25011" data-usd="7391.83">
# $7391.83
# </span>
# </td>
# <td class="text-right">
# <span data-format-percentage="" data-format-value="0">0.00</span>%
# </td>
# <td class="text-right stale-box">1 hour ago</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="clear"></div>
# * Price Excluded<br/>
# ** Volume Excluded - No Trading Fees<br/>
# *** Price/Volume Excluded - Outlier Detected
# </div>
# </div>
# <div class="tab-pane" id="social">
# <div class="tab-header">
# <h2 class="pull-left">Ripple Social Media Feeds</h2>
# <div class="clear"></div>
# </div>
# <div class="row">
# <div class="col-sm-6 text-left">
# <a class="twitter-timeline" data-screen-name="Ripple" data-widget-id="506520279636377601" href="https://twitter.com/Ripple">Tweets by @Ripple</a>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");</script>
# </div>
# <div class="col-sm-6 text-left" id="reddit">
# </div>
# </div>
# </div>
# <div class="tab-pane" id="tools">
# <div class="tab-header">
# <h2 class="pull-left">Tools for Ripple</h2>
# <div class="clear bottom-margin-1x"></div>
# </div>
# <div class="row">
# <div class="col-md-2">
# <strong>Website Widget</strong>
# </div>
# <div class="col-md-6">
# <textarea class="form-control" data-snippet-container="" rows="6">&lt;script type="text/javascript" src="https://files.coinmarketcap.com/static/widget/currency.js"&gt;&lt;/script&gt;
# &lt;div class="coinmarketcap-currency-widget" data-currency="ripple" data-base="USD"  data-secondary="BTC"&gt;&lt;/div&gt;</textarea>
# <br/>
# <a class="btn btn-primary pull-right" href="/widget/?c=ripple" role="button" style="width:100%" target="_blank">Customize this widget</a>
# <div class="clear"></div>
# </div>
# <div class="col-md-4">
# <div class="coinmarketcap-currency-widget" data-base="USD" data-currency="ripple" data-secondary="BTC" data-ticker="true" style=""></div>
# </div>
# </div>
# <div class="row">
# <div class="clear bottom-margin-2x"></div>
# <div class="col-md-12"><hr/></div>
# <div class="clear bottom-margin-2x"></div>
# <div class="col-md-2">
# <strong>API Ticker</strong>
# </div>
# <div class="col-md-6">
# <a href="https://api.coinmarketcap.com/v1/ticker/ripple/" target="_blank">https://api.coinmarketcap.com/v1/ticker/ripple/</a>
# </div>
# <div class="col-md-4">
# <a class="text-small" href="/api/" target="_blank">[API Docs]</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" data-apidomain="https://graphs2.coinmarketcap.com" data-mobile="False" data-platform="False" data-platformsymbol="" data-slug="ripple" id="metadata">
# </div>
# <hr/>
# <div class="row text-center" id="leaderboard-bottom">
# <div class="centered leaderboard" id="div-gpt-ad-1488495260324-8">
# <script>
#                                     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1488495260324-8'); });
#                                     </script>
# </div>
# </div>
# <hr/>
# <div class="row" id="footer">
# <div class="col-xs-12 col-md-5">
# <div>
# © 2018 CoinMarketCap |
# <a href="/advertising/" target="_blank">Advertise</a> |
# <a href="/api/">API</a> |
# <a href="/disclaimer/">Disclaimer</a> |
# <a href="/faq/">FAQ</a> |
# <a href="/request/" target="_blank">Request Form</a>
# </div>
# <br/>
# <div>
# Night Mode:
# <div class="btn-group" data-toggle="buttons">
# <label class="btn btn-default btn-sm" data-night-mode-off="">
# <input type="radio"/> Off
# </label>
# <label class="btn btn-default btn-sm" data-night-mode-on="">
# <input type="radio"/> On
# </label>
# </div>
# </div>
# <div class="visible-sm visible-xs"><br/></div>
# </div>
# <div class="clearfix visible-sm visible-xs"></div>
# <div class="col-md-1 text-center">
# <a href="https://www.facebook.com/CoinMarketCap" target="_blank"><img alt="twitter" class="icon-social" src="https://s2.coinmarketcap.com/static/cloud/img/facebook_logo.png"/></a>
# <a href="https://twitter.com/CoinMarketCap" target="_blank"><img alt="twitter" class="icon-social" src="https://s2.coinmarketcap.com/static/cloud/img/twitter_logo.png"/></a>
# </div>
# <div class="clearfix visible-sm visible-xs"><br/></div>
# <div class="col-xs-12 col-md-6 text-right">
# Donate BTC: <a class="pointer" data-target="#donate_btc" data-toggle="modal">3CMCRgEm8HVz3DrWaCCid3vAANE42jcEv9</a><br/>
# Donate LTC: <a class="pointer" data-target="#donate_ltc" data-toggle="modal">LTdsVS8VDw6syvfQADdhf2PHAm3rMGJvPX</a><br/>
# Donate ETH: <a class="pointer" data-target="#donate_eth" data-toggle="modal">0x0074709077B8AE5a245E4ED161C971Dc4c3C8E2B</a><br/>
# Donate BCH: <a class="pointer" data-target="#donate_bch" data-toggle="modal">1LVXG4Z4oF6TrJfmUfSuLX8nqb8c5eCwha</a>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="donate_btc_label" class="modal fade" id="donate_btc" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header text-center">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="donate_btc_label">Donate Bitcoin</h4>
# </div>
# <div class="modal-body text-center">
# <strong>3CMCRgEm8HVz3DrWaCCid3vAANE42jcEv9</strong> <br/> <img alt="Donate Bitcoin" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_bitcoin.png"/><br/>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="donate_ltc_label" class="modal fade" id="donate_ltc" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header text-center">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="donate_ltc_label">Donate Litecoin</h4>
# </div>
# <div class="modal-body text-center">
# <strong>LTdsVS8VDw6syvfQADdhf2PHAm3rMGJvPX</strong> <br/> <img alt="Donate Litecoin" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_litecoin.png"/><br/>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="donate_eth_label" class="modal fade" id="donate_eth" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header text-center">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="donate_eth_label">Donate Ethereum</h4>
# </div>
# <div class="modal-body text-center">
# <strong>0x0074709077B8AE5a245E4ED161C971Dc4c3C8E2B</strong> <br/> <img alt="Donate Ethereum" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_ethereum.png"/><br/>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="donate_bch_label" class="modal fade" id="donate_bch" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header text-center">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="donate_bch_label">Donate Bitcoin Cash</h4>
# </div>
# <div class="modal-body text-center">
# <strong>1LVXG4Z4oF6TrJfmUfSuLX8nqb8c5eCwha</strong> <br/> <img alt="Donate Bitcoin Cash" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_bitcoin_cash.png"/><br/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-2 hidden-xs hidden-sm hidden-md">
# <div style="margin-top:200px;float:right;">
# <div style="width:160px; height:600px;">
# <div class="skyscraper" id="div-gpt-ad-1488495260324-10">
# <script>
#                                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1488495260324-10'); });
#                                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div data-staticdomain="files.coinmarketcap.com" id="static_domain"></div>
# <div data-source-link-prefix="/currencies/" data-template-name="quick_search" id="quick-search-opts"></div>
# <div data-aud="0.7871325861870825" data-bch="1326.8972080857907" data-brl="0.30716926931188554" data-btc="9252.7815986907881" data-cad="0.7958007187672091" data-chf="1.0729061164231886" data-clp="0.0016803898504453032" data-cny="0.15756964578343627" data-czk="0.048823078200363766" data-dkk="0.16636917086097208" data-eth="904.93693068372011" data-eur="1.239444580094768" data-gbp="1.3953696055011051" data-hkd="0.1278518963632528" data-huf="0.003970203621818254" data-idr="7.336286173454308e-05" data-ils="0.2831393356984906" data-inr="0.015600867408227897" data-jpy="0.00934420609580965" data-krw="0.0009279967334514984" data-ltc="206.065249944085" data-mxn="0.05373344546428733" data-myr="0.25621487614316674" data-nok="0.12745924649917248" data-nzd="0.7332550216970161" data-php="0.01917030902538149" data-pkr="0.009040773890245005" data-pln="0.29733799242144926" data-rub="0.017520775259263672" data-sek="0.1248955716901206" data-sgd="0.7588531603957571" data-thb="0.031895891809134984" data-try="0.26377846829119034" data-twd="0.03428708576914505" data-usd="1" data-xrp="1.074347535932652" data-zar="0.08512674819482345" id="currency-exchange-rates"></div>
# <script src="https://s2.coinmarketcap.com/static/cloud/compressed/base.b46f1b72.min.js"></script>
# <script src="https://s2.coinmarketcap.com/static/cloud/compressed/highcharts.df6483be.js"></script>
# <script src="https://s2.coinmarketcap.com/static/cloud/compressed/detail.1d52e004.min.js"></script>
# <script>
# $(document).ready(function() {
#
#         /* Reddit lazy load hack */
#         var oScript = document.createElement("script");
#         document.write = function(text) {
#             document.getElementById("reddit").innerHTML += text;
#         };
#         oScript.src = "https://www.reddit.com/r/ripple.embed?limit=9";
#         document.body.appendChild(oScript);
#
#
#     setTimeout(function() {
#         document.title = "Ripple (XRP) $1.09 (5.89%) | CoinMarketCap";
#     }, 10000);
#
#
# });
#
# const PHRASES = {
#     contextButtonTitle: "Chart context menu",
#     downloadCSV: "Download CSV",
#     downloadJPEG: "Download JPEG image",
#     downloadPDF: "Download PDF document",
#     downloadPNG: "Download PNG image",
#     downloadSVG: "Download SVG vector image",
#     downloadXLS: "Download XLS",
#     drillUpText: "Back to {series.name}",
#     loading: "Loading...",
#     noData: "No data to display",
#     printChart: "Print chart",
#     resetZoom: "Reset zoom",
#     resetZoomTitle: "Reset zoom level 1:1",
#     viewData: "View data table",
#     '1d': "1d",
#     '7d': "7d",
#     '1m': "1m",
#     '3m': "3m",
#     '1y': "1y",
#     'ytd': "YTD",
#     'all': "ALL",
#     dateFormat: "%A, %b %d %Y, %H:%M:%S UTC",
#     months: {
#         full: {mar: 'March',feb: 'February',aug: 'August',sep: 'September',apr: 'April',jun: 'June',jul: 'July',jan: 'January',may: 'May',nov: 'November',dec: 'December',oct: 'October'},
#         short: {mar: 'Mar',feb: 'Feb',aug: 'Aug',sep: 'Sep',apr: 'Apr',jun: 'Jun',jul: 'Jul',jan: 'Jan',may: 'May',nov: 'Nov',dec: 'Dec',oct: 'Oct'}
#     },
#     weekdays: {
#         full: {wed: 'Wednesday',sun: 'Sunday',thu: 'Thursday',mon: 'Monday',fri: 'Friday',tue: 'Tuesday',sat: 'Saturday'},
#         short: {wed: 'Wed',sun: 'Sun',thu: 'Thu',mon: 'Mon',fri: 'Fri',tue: 'Tue',sat: 'Sat'}
#     },
#     emptyTable: "No data available in table",
#     zeroRecords: "No matching records found",
#     sortAscending: ": activate to sort column ascending",
#     sortDescending: ": activate to sort column descending",
#     'K': "K",
#     'M': "M",
#     'B': "B",
#     'T': "T",
#     chartTitle: "Ripple Charts",
#     marketCap: "Market Cap",
#     priceUSD: "Price (USD)",
#     priceBTC: "Price (BTC)",
#
#     volume: "24h Vol"
# };
# var polyglot = new Polyglot({phrases: PHRASES});
# </script>
# <script>
#             $( document ).ready(function() {
#                 // GTM Session Set
#                 var maxExpire = new Date('2038-01-19 00:00:00');
#                 if (Cookies.get("gtm_session_first") === undefined) {
#                     Cookies.set("gtm_session_first", new Date(), {expires: maxExpire})
#                 }
#
#                 Cookies.set("gtm_session_last", new Date(), {expires: maxExpire})
#
#                 // Header Banner Prefs
#                 $(".header-banner-close").on('click', function () {
#                     Cookies.set("header-banner-noshow", "1", {expires: 1})
#                     $('#header-banner-wrapper').fadeOut();
#                     dataLayer.push({
#                         'event': 'customEvent',
#                         'eventCategory': 'Header Banner',
#                         'eventAction': 'Close',
#                     });
#                 });
#
#             });
#
#             $('[data-language-toggle]').click(function () {
#                 dataLayer.push({
#                     'event': 'customEvent',
#                     'eventCategory': 'Language Dropdown',
#                     'eventAction': 'Language Selected',
#                     'eventLabel': $(this).data('language-toggle')
#                 });
#             });
#
#             var language = $('[data-language-toggle="' + 'en' + '"]').html();
#             $('[data-language-dropdown]').html(language);
#
#             NightMode.initSwitch();
#
#         </script>
# <script src="https://files.coinmarketcap.com/static/sponsored/xinfin/assets/js/main.js"></script>
# <script src="https://files.coinmarketcap.com/static/sponsored/xinfin/assets/js/particles/particles.js"></script>
# <script src="https://files.coinmarketcap.com/static/sponsored/xinfin/assets/js/particles/particles-animation.js"></script>
# </body>
# </html>

# %%
headers = soup.findAll('h2')
headers
# Out:
# [<h2><a class="navbar-brand" href="/">CoinMarketCap</a></h2>,
#  <h2 class="pull-left">Ripple Markets</h2>,
#  <h2 class="pull-left">Ripple Social Media Feeds</h2>,
#  <h2 class="pull-left">Tools for Ripple</h2>]

# %%
social_media = headers[-2]

# %%
twitter_link = social_media.find_next('a',{'class':'twitter-timeline'})['href']
twitter_link
# Out:
# 'https://twitter.com/Ripple'

# %%
twitter_name = twitter_link.strip('/').split('/')[-1]
twitter_name
# Out:
# 'Ripple'

# %%
def get_twitter_handle(soup):
    # find section headers
    headers = soup.findAll('h2')
    social_media = headers[-2]
    try: 
        twitter_link = social_media.find_next('a',{'class':'twitter-timeline'})['href']
    except:
        print('no twitter_link')
       # print(social_media.find_next('div',{'class':'row'}))
        return ''
        
    twitter_name = twitter_link.strip('/').split('/')[-1]
    return twitter_name
for filename in files:
    html = open(filename,'r').read()
    soup = soup = BeautifulSoup(html,'lxml')
    # function to parse html here
    print(get_twitter_handle(soup))
# Out:
# no twitter_link
#
# no twitter_link
#
# ethereumproject
# LitecoinProject
# Ripple

# %% [markdown]
# # APIs
# For fast, efficient and ***reliable*** data collection.
#
# Only catch is that they control the amounts, and which endpoints you can collect
#
# also they **change**.
#     - e.g. facebook cancelled
#         - querying friendship relations (without having using signing up to your app),
#         - group activity without admin rights,
#         - and most recently the ability to trace public activity (likes and comments) without admin rights.
#     - twitter (and more recently facebook) will not let you collect all historic activity --> streaming data.
#
# Begins with reading the docs...
# - getting authentification - creating apps, getting and renewing tokens -
# - building queries.
# - ratelimiting and pagination.
#
# Often comes in the Json format. --> nested dictionaries and lists.
#
# Example: Explore the facebook api here: https://developers.facebook.com/tools/explorer/

# %% [markdown]
# ## APIS: Collect data from Twitter

# %%
# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials that you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation

CONSUMER_KEY=""
CONSUMER_SECRET=""
OAUTH_TOKEN=""
OAUTH_TOKEN_SECRET=""

# %%
#pickle.dump([CONSUMER_KEY,CONSUMER_SECRET,OAUTH_TOKEN,OAUTH_TOKEN_SECRET],open('twitter_credentials.pkl','wb'))
CONSUMER_KEY,CONSUMER_SECRET,OAUTH_TOKEN,OAUTH_TOKEN_SECRET = pickle.load(open('twitter_credentials.pkl','rb'))

# %%
# answer from https://stackoverflow.com/questions/33308634/how-to-perform-oauth-when-doing-twitter-scrapping-with-python-requests
from requests_oauthlib import OAuth1
#url = 'https://api.twitter.com/1.1/account/verify_credentials.json' # verify that your authorization works.
#url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=singularity_net&count=5000' # get timeline

# Description of the call https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
url = 'https://api.twitter.com/1.1/followers/list.json?cursor=-1&screen_name=%s&count=5000'%twitter_name

auth = OAuth1(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
response = requests.get(url, auth=auth).json()

# %%
# define container to store the responses.
responses = []

# %%
cursor = -1 # start with -1
url = 'https://api.twitter.com/1.1/followers/list.json?cursor=%d&screen_name=singularity_net&count=5000' %cursor
auth = OAuth1(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
response = requests.get(url, auth=auth).json()
responses.append(response)
count = 0
while cursor!=0:
    time.sleep(1)
    cursor = response['next_cursor']
    url = 'https://api.twitter.com/1.1/followers/list.json?cursor=%d&screen_name=singularity_net&count=5000'%cursor
    response = requests.get(url, auth=auth).json()
    # dump response
    responses.append(response)
    count+=1
    if count%10==0:
        print(count,end=' ')
#response
# Out:
# 10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-e748b2e4110a> in <module>()
#       7 while cursor!=0:
#       8     time.sleep(1)
# ----> 9     cursor = response['next_cursor']
#      10     url = 'https://api.twitter.com/1.1/followers/list.json?cursor=%d&screen_name=singularity_net&count=5000'%cursor
#      11     response = requests.get(url, auth=auth).json()
#
# KeyError: 'next_cursor'

# %%
response
# Out:
# {'errors': [{'code': 88, 'message': 'Rate limit exceeded'}]}

# %% [markdown]
# Packages: python-twitter and tweepy.

# %% [markdown]
# # Exercise(4)
# - Collect the link to each of the crypto-companies' github page (Source Code) and get data from the api.
#     * E.g. Get the contributors of the repository. - Count the number of unique contributors.
#     * Get events.
#     * Get forks.
#
#
# ## GITHUB API
# Check the docs:
# https://developer.github.com/v3/
#
# ### Practice with some calls###
# The github api is nice to work with because it provides links to further calls that can be made.
# * This will list basic queries: https://api.github.com/
# * Play around with it: e.g. https://api.github.com/repos/singnet/singnet/contributors
#
# ### Read about paging
# here: https://developer.github.com/v3/guides/traversing-with-pagination/
# ### Rate limits
# For practice you can make calls without authorization. However if you need large amounts of data you need an authorization token.
# This means the standard procedure: https://developer.github.com/apps/building-oauth-apps/authorization-options-for-oauth-apps/
#     * Create an app here (under developers settings): https://github.com/settings/, collect client_id and client_secret for the app.
#     * Let a user (yourself) Authorize your app. Using the specified procedure described https://github.com/login/oauth/authorize?client_id=(indsæt_client_id).
#     * Get the code returned (look at the url in the top of the browser).
#     * Use the code, client_id, client_secret to request an access_token: 'https://github.com/login/oauth/access_token?code=%s&client_id=%s&client_secret=%s'%(code,client_id,client_secret)

# %% [markdown]
# ## ressource a guide to authentication

# %%
# look at the guide for making authorized calls:
# https://developer.github.com/apps/building-oauth-apps/authorization-options-for-oauth-apps/
client_id = ''#found in the settings of your newly generated test app
client_secret = '' # also found in the settings of your app
code = ''# found using the call  https://github.com/login/oauth/authorize?client_id=%s'%client_id

# %%
#pickle.dump([client_id,client_secret,code],open('github_credentials.pkl','wb'))
client_id,client_secret,code = pickle.load(open('github_credentials.pkl','rb'))

# %%
# as described in the docs https://developer.github.com/apps/building-oauth-apps/authorization-options-for-oauth-apps/
url = 'https://github.com/login/oauth/access_token?code=%s&client_id=%s&client_secret=%s'%(code,client_id,client_secret)
response = request(url)
token = response.text.split('access_token=')[0].split('&')[0]

# %%
#pickle.dump(token,open('gittoken','wb'))
token = pickle.load(open('gittoken','rb'))

# %% [markdown]
# ## Solution (4)

# %%
# Read in the raw_html
path = 'crypto_data/coinmarket_html/'
files = [path+filename for filename in listdir(path)]
for filename in files:
    html = open(filename,'r').read()
    soup = soup = BeautifulSoup(html,'lxml')
    break

# %%
link = soup.find('a',text='Source Code')['href']
git_screen_name = link.strip('/').split('/')[-1]
link,git_screen_name
# Out:
# ('https://github.com/bitcoin/', 'bitcoin')

# %%
url = 'https://api.github.com/users/%s?access_token=%s'%(git_screen_name,token)
response = request(url)
response.json()
# Out:
# {'avatar_url': 'https://avatars2.githubusercontent.com/u/528860?v=4',
#  'bio': None,
#  'blog': 'http://bitcoin.org/',
#  'company': None,
#  'created_at': '2010-12-18T21:50:48Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/bitcoin/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/bitcoin/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/bitcoin/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/bitcoin/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/bitcoin',
#  'id': 528860,
#  'location': None,
#  'login': 'bitcoin',
#  'name': 'Bitcoin',
#  'organizations_url': 'https://api.github.com/users/bitcoin/orgs',
#  'public_gists': 0,
#  'public_repos': 4,
#  'received_events_url': 'https://api.github.com/users/bitcoin/received_events',
#  'repos_url': 'https://api.github.com/users/bitcoin/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/bitcoin/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/bitcoin/subscriptions',
#  'type': 'Organization',
#  'updated_at': '2016-07-04T08:31:16Z',
#  'url': 'https://api.github.com/users/bitcoin'}

# %%
# lets look at some contributors

url = 'https://api.github.com/repos/singnet/singnet/contributors?access_token=%s'%token
response = request(url)
response.json()
# Out:
# [{'avatar_url': 'https://avatars0.githubusercontent.com/u/1048706?v=4',
#   'contributions': 219,
#   'events_url': 'https://api.github.com/users/inflector/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/inflector/followers',
#   'following_url': 'https://api.github.com/users/inflector/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/inflector/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/inflector',
#   'id': 1048706,
#   'login': 'inflector',
#   'organizations_url': 'https://api.github.com/users/inflector/orgs',
#   'received_events_url': 'https://api.github.com/users/inflector/received_events',
#   'repos_url': 'https://api.github.com/users/inflector/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/inflector/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/inflector/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/inflector'},
#  {'avatar_url': 'https://avatars2.githubusercontent.com/u/189265?v=4',
#   'contributions': 145,
#   'events_url': 'https://api.github.com/users/jensenbox/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jensenbox/followers',
#   'following_url': 'https://api.github.com/users/jensenbox/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jensenbox/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jensenbox',
#   'id': 189265,
#   'login': 'jensenbox',
#   'organizations_url': 'https://api.github.com/users/jensenbox/orgs',
#   'received_events_url': 'https://api.github.com/users/jensenbox/received_events',
#   'repos_url': 'https://api.github.com/users/jensenbox/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jensenbox/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jensenbox/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jensenbox'},
#  {'avatar_url': 'https://avatars0.githubusercontent.com/u/3596602?v=4',
#   'contributions': 58,
#   'events_url': 'https://api.github.com/users/tiero/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/tiero/followers',
#   'following_url': 'https://api.github.com/users/tiero/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/tiero/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/tiero',
#   'id': 3596602,
#   'login': 'tiero',
#   'organizations_url': 'https://api.github.com/users/tiero/orgs',
#   'received_events_url': 'https://api.github.com/users/tiero/received_events',
#   'repos_url': 'https://api.github.com/users/tiero/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/tiero/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/tiero/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/tiero'},
#  {'avatar_url': 'https://avatars2.githubusercontent.com/u/1233579?v=4',
#   'contributions': 24,
#   'events_url': 'https://api.github.com/users/akolonin/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/akolonin/followers',
#   'following_url': 'https://api.github.com/users/akolonin/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/akolonin/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/akolonin',
#   'id': 1233579,
#   'login': 'akolonin',
#   'organizations_url': 'https://api.github.com/users/akolonin/orgs',
#   'received_events_url': 'https://api.github.com/users/akolonin/received_events',
#   'repos_url': 'https://api.github.com/users/akolonin/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/akolonin/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/akolonin/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/akolonin'},
#  {'avatar_url': 'https://avatars1.githubusercontent.com/u/18440657?v=4',
#   'contributions': 19,
#   'events_url': 'https://api.github.com/users/altafan/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/altafan/followers',
#   'following_url': 'https://api.github.com/users/altafan/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/altafan/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/altafan',
#   'id': 18440657,
#   'login': 'altafan',
#   'organizations_url': 'https://api.github.com/users/altafan/orgs',
#   'received_events_url': 'https://api.github.com/users/altafan/received_events',
#   'repos_url': 'https://api.github.com/users/altafan/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/altafan/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/altafan/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/altafan'},
#  {'avatar_url': 'https://avatars0.githubusercontent.com/u/599918?v=4',
#   'contributions': 12,
#   'events_url': 'https://api.github.com/users/andrelashley/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/andrelashley/followers',
#   'following_url': 'https://api.github.com/users/andrelashley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/andrelashley/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/andrelashley',
#   'id': 599918,
#   'login': 'andrelashley',
#   'organizations_url': 'https://api.github.com/users/andrelashley/orgs',
#   'received_events_url': 'https://api.github.com/users/andrelashley/received_events',
#   'repos_url': 'https://api.github.com/users/andrelashley/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/andrelashley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/andrelashley/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/andrelashley'},
#  {'avatar_url': 'https://avatars1.githubusercontent.com/u/477642?v=4',
#   'contributions': 3,
#   'events_url': 'https://api.github.com/users/pennachin/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/pennachin/followers',
#   'following_url': 'https://api.github.com/users/pennachin/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pennachin/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/pennachin',
#   'id': 477642,
#   'login': 'pennachin',
#   'organizations_url': 'https://api.github.com/users/pennachin/orgs',
#   'received_events_url': 'https://api.github.com/users/pennachin/received_events',
#   'repos_url': 'https://api.github.com/users/pennachin/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/pennachin/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pennachin/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/pennachin'},
#  {'avatar_url': 'https://avatars1.githubusercontent.com/u/7621705?v=4',
#   'contributions': 2,
#   'events_url': 'https://api.github.com/users/decanus/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/decanus/followers',
#   'following_url': 'https://api.github.com/users/decanus/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/decanus/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/decanus',
#   'id': 7621705,
#   'login': 'decanus',
#   'organizations_url': 'https://api.github.com/users/decanus/orgs',
#   'received_events_url': 'https://api.github.com/users/decanus/received_events',
#   'repos_url': 'https://api.github.com/users/decanus/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/decanus/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/decanus/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/decanus'},
#  {'avatar_url': 'https://avatars3.githubusercontent.com/u/5485523?v=4',
#   'contributions': 1,
#   'events_url': 'https://api.github.com/users/TScottJ/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/TScottJ/followers',
#   'following_url': 'https://api.github.com/users/TScottJ/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/TScottJ/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/TScottJ',
#   'id': 5485523,
#   'login': 'TScottJ',
#   'organizations_url': 'https://api.github.com/users/TScottJ/orgs',
#   'received_events_url': 'https://api.github.com/users/TScottJ/received_events',
#   'repos_url': 'https://api.github.com/users/TScottJ/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/TScottJ/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/TScottJ/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/TScottJ'}]

# %%
# list of possible calls: https://api.github.com/

# check your ratelimit: 'https://api.github.com/rate_limit?access_token=%s'%token
#interesting calls
# https://api.github.com/repos/singnet/singnet/contributors # contributors to a project, create a network of co-contributors.
# 'https://api.github.com/repos/singnet/singnet/forks'
#'https://api.github.com/repos/singnet/singnet/events' # get all events (watch and fork, pull, push and commit events), are they coordinated?
## are they from bots. e.g. dmonroe3 who follows 5 blockchain things.
## Also includes push events and messages.
# 'https://api.github.com/users/dmonroe3/followers # get the followers of a user
# https://api.github.com/users/thinxtank # get basic info about a user.

# %% [markdown]
# ### paging

# %%
url ='https://api.github.com/repos/singnet/singnet/forks'
response = request(url)
response.headers['Link'] # Here you can read how many pages to page. read here: https://developer.github.com/v3/guides/traversing-with-pagination/
# Out:
# '<https://api.github.com/repositories/100654282/forks?page=2>; rel="next", <https://api.github.com/repositories/100654282/forks?page=3>; rel="last"'

# %% [markdown]
# # Perspectives
# ## Regex
# For cleaning, further extraction of information from html and text, you need to learn Regular expressions --> More to come in the future sessions.
#
#     - For now. Go play around at https://www.regexr.com.
#
# or do the following exercises:
# - Locate the link to the website of each of the blockchain companies.
# - Try to find the number of doctors displayed on the website of each project (frontpage or crawl the whole map, while your at it see if you can do some other stats about the team.). Match the name after the Dr. prefix.
# - Find the numbers thrown around on each website: $9234 million / trillion / thousands.
#     - Find the previous word before the number.

# %% [markdown]
# # Perspectives (2)
# ## Common scenarios
# Tabular data from html.
#     - Beautifulsoup: Google is your friend (e.g. https://stackoverflow.com/questions/23377533/python-beautifulsoup-parsing-table)
#     - Pandas: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html
#
# Interactions(clicking, scrolling, logins etc):
#     * Use selenium.
#         - Select element (using css-selector path or search as in beautifulsoup)
#             - element.click()
#             - element.send_keys()
#         - scrolling (google "scroll to the bottom selenium python")

# %% [markdown]
# # Perspectives(3)
# ### Reliability
# EDA
